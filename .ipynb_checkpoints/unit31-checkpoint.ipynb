# %%
import requests
r = requests.get('http://www.citibikenyc.com/stations/json')

# %%
r.text
# Out:
# u'{"executionTime":"2015-03-14 10:45:01 AM","stationBeanList":[{"id":72,"stationName":"W 52 St & 11 Ave","availableDocks":27,"totalDocks":39,"latitude":40.76727216,"longitude":-73.99392888,"statusValue":"In Service","statusKey":1,"availableBikes":10,"stAddress1":"W 52 St & 11 Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":79,"stationName":"Franklin St & W Broadway","availableDocks":31,"totalDocks":33,"latitude":40.71911552,"longitude":-74.00666661,"statusValue":"In Service","statusKey":1,"availableBikes":2,"stAddress1":"Franklin St & W Broadway","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":82,"stationName":"St James Pl & Pearl St","availableDocks":23,"totalDocks":27,"latitude":40.71117416,"longitude":-74.00016545,"statusValue":"In Service","statusKey":1,"availableBikes":3,"stAddress1":"St James Pl & Pearl St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":83,"stationName":"Atlantic Ave & Fort Greene Pl","availableDocks":54,"totalDocks":62,"latitude":40.68382604,"longitude":-73.97632328,"statusValue":"In Service","statusKey":1,"availableBikes":7,"stAddress1":"Atlantic Ave & Fort Greene Pl","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":116,"stationName":"W 17 St & 8 Ave","availableDocks":34,"totalDocks":39,"latitude":40.74177603,"longitude":-74.00149746,"statusValue":"In Service","statusKey":1,"availableBikes":3,"stAddress1":"W 17 St & 8 Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":119,"stationName":"Park Ave & St Edwards St","availableDocks":13,"totalDocks":19,"latitude":40.69608941,"longitude":-73.97803415,"statusValue":"In Service","statusKey":1,"availableBikes":5,"stAddress1":"Park Ave & St Edwards St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":120,"stationName":"Lexington Ave & Classon Ave","availableDocks":12,"totalDocks":19,"latitude":40.68676793,"longitude":-73.95928168,"statusValue":"In Service","statusKey":1,"availableBikes":6,"stAddress1":"Lexington Ave & Classon Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":127,"stationName":"Barrow St & Hudson St","availableDocks":28,"totalDocks":31,"latitude":40.73172428,"longitude":-74.00674436,"statusValue":"In Service","statusKey":1,"availableBikes":2,"stAddress1":"Barrow St & Hudson St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":128,"stationName":"MacDougal St & Prince St","availableDocks":17,"totalDocks":30,"latitude":40.72710258,"longitude":-74.00297088,"statusValue":"In Service","statusKey":1,"availableBikes":12,"stAddress1":"MacDougal St & Prince St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":137,"stationName":"E 56 St & Madison Ave","availableDocks":42,"totalDocks":46,"latitude":40.761628,"longitude":-73.972924,"statusValue":"In Service","statusKey":1,"availableBikes":3,"stAddress1":"E 56 St & Madison Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":null,"landMark":""},{"id":143,"stationName":"Clinton St & Joralemon St","availableDocks":21,"totalDocks":24,"latitude":40.69239502,"longitude":-73.99337909,"statusValue":"In Service","statusKey":1,"availableBikes":2,"stAddress1":"Clinton St & Joralemon St","stAddress2":"","city":"","postalCode":"","locatio ...

# %%
r.json()
# Out:
# {u'executionTime': u'2015-03-14 10:45:01 AM',
#  u'stationBeanList': [{u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 72,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.76727216,
#    u'location': u'',
#    u'longitude': -73.99392888,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 79,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71911552,
#    u'location': u'',
#    u'longitude': -74.00666661,
#    u'postalCode': u'',
#    u'stAddress1': u'Franklin St & W Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Franklin St & W Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 82,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71117416,
#    u'location': u'',
#    u'longitude': -74.00016545,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 54,
#    u'city': u'',
#    u'id': 83,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68382604,
#    u'location': u'',
#    u'longitude': -73.97632328,
#    u'postalCode': u'',
#    u'stAddress1': u'Atlantic Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Atlantic Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 62},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 116,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74177603,
#    u'location': u'',
#    u'longitude': -74.00149746,
#    u'postalCode': u'',
#    u'stAddress1': u'W 17 St & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 17 St & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 119,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69608941,
#    u'location': u'',
#    u'longitude': -73.97803415,
#    u'postalCode': u'',
#    u'stAddress1': u'Park Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Park Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 120,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68676793,
#    u'location': u'',
#    u'longitude': -73.95928168,
#    u'postalCode': u'',
#    u'stAddress1': u'Lexington Ave & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Lexington Ave & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 127,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73172428,
#    u'location': u'',
#    u'longitude': -74.00674436,
#    u'postalCode': u'',
#    u'stAddress1': u'Barrow St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Barrow St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 128,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72710258,
#    u'location': u'',
#    u'longitude': -74.00297088,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 42,
#    u'city': u'',
#    u'id': 137,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.761628,
#    u'location': u'',
#    u'longitude': -73.972924,
#    u'postalCode': u'',
#    u'stAddress1': u'E 56 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 56 St & Madison Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 46},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 143,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69239502,
#    u'location': u'',
#    u'longitude': -73.99337909,
#    u'postalCode': u'',
#    u'stAddress1': u'Clinton St & Joralemon St',
#    u'stAddress2': u'',
#    u'stationName': u'Clinton St & Joralemon St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 144,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69839895,
#    u'location': u'',
#    u'longitude': -73.98068914,
#    u'postalCode': u'',
#    u'stAddress1': u'Nassau St & Navy St',
#    u'stAddress2': u'',
#    u'stationName': u'Nassau St & Navy St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 146,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71625008,
#    u'location': u'',
#    u'longitude': -74.0091059,
#    u'postalCode': u'',
#    u'stAddress1': u'Hudson St & Reade St',
#    u'stAddress2': u'',
#    u'stationName': u'Hudson St & Reade St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 147,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71542197,
#    u'location': u'',
#    u'longitude': -74.01121978,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich St & Warren St',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich St & Warren St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 150,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7208736,
#    u'location': u'',
#    u'longitude': -73.98085795,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue C',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue C',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 151,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7218158,
#    u'location': u'',
#    u'longitude': -73.99720307,
#    u'postalCode': u'',
#    u'stAddress1': u'Cleveland Pl & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Cleveland Pl & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 152,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71473993,
#    u'location': u'',
#    u'longitude': -74.00910627,
#    u'postalCode': u'',
#    u'stAddress1': u'Warren St & Church St',
#    u'stAddress2': u'',
#    u'stationName': u'Warren St & Church St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 46,
#    u'city': u'',
#    u'id': 153,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.752062307,
#    u'location': u'',
#    u'longitude': -73.9816324043,
#    u'postalCode': u'',
#    u'stAddress1': u'E 40 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 40 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 157,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69089272,
#    u'location': u'',
#    u'longitude': -73.99612349,
#    u'postalCode': u'',
#    u'stAddress1': u'Henry St & Atlantic Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Henry St & Atlantic Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 160,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.748238,
#    u'location': u'',
#    u'longitude': -73.978311,
#    u'postalCode': u'',
#    u'stAddress1': u'E 37 St & Lexington Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 37 St & Lexington Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 161,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72917025,
#    u'location': u'',
#    u'longitude': -73.99810231,
#    u'postalCode': u'',
#    u'stAddress1': u'LaGuardia Pl & W 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'LaGuardia Pl & W 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 164,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75323098,
#    u'location': u'',
#    u'longitude': -73.97032517,
#    u'postalCode': u'',
#    u'stAddress1': u'E 47 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 47 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 167,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7489006,
#    u'location': u'',
#    u'longitude': -73.97604882,
#    u'postalCode': u'',
#    u'stAddress1': u'E 39 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 39 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 37,
#    u'city': u'',
#    u'id': 168,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73971301,
#    u'location': u'',
#    u'longitude': -73.99456405,
#    u'postalCode': u'',
#    u'stAddress1': u'W 18 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 18 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 173,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.76064679,
#    u'location': u'',
#    u'longitude': -73.98442659,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 49 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 49 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 51},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 174,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7381765,
#    u'location': u'',
#    u'longitude': -73.97738662,
#    u'postalCode': u'',
#    u'stAddress1': u'E 25 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 25 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 44,
#    u'city': u'',
#    u'id': 195,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70905623,
#    u'location': u'',
#    u'longitude': -74.01043382,
#    u'postalCode': u'',
#    u'stAddress1': u'Liberty St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Liberty St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 212,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74334935,
#    u'location': u'',
#    u'longitude': -74.00681753,
#    u'postalCode': u'',
#    u'stAddress1': u'W 16 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 16 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 28},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 216,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70037867,
#    u'location': u'',
#    u'longitude': -73.99548059,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia Heights & Cranberry St',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia Heights & Cranberry St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 217,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70277159,
#    u'location': u'',
#    u'longitude': -73.99383605,
#    u'postalCode': u'',
#    u'stAddress1': u'Old Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Old Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 218,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69028437,
#    u'location': u'',
#    u'longitude': -73.98707105,
#    u'postalCode': u'',
#    u'stAddress1': u'Gallatin Pl & Livingston St',
#    u'stAddress2': u'',
#    u'stationName': u'Gallatin Pl & Livingston St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 38},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 223,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73781509,
#    u'location': u'',
#    u'longitude': -73.99994661,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 7 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 7 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 224,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71146364,
#    u'location': u'',
#    u'longitude': -74.00552427,
#    u'postalCode': u'',
#    u'stAddress1': u'Spruce St & Nassau St',
#    u'stAddress2': u'',
#    u'stationName': u'Spruce St & Nassau St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 225,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74195138,
#    u'location': u'',
#    u'longitude': -74.00803013,
#    u'postalCode': u'',
#    u'stAddress1': u'W 14 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 14 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 51,
#    u'city': u'',
#    u'id': 228,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7546011026,
#    u'location': u'',
#    u'longitude': -73.971878855,
#    u'postalCode': u'',
#    u'stAddress1': u'E 48 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 48 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 229,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72743423,
#    u'location': u'',
#    u'longitude': -73.99379025,
#    u'postalCode': u'',
#    u'stAddress1': u'Great Jones St',
#    u'stAddress2': u'',
#    u'stationName': u'Great Jones St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 232,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69597683,
#    u'location': u'',
#    u'longitude': -73.99014892,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza E & Tillary St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza E & Tillary St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 233,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69246277,
#    u'location': u'',
#    u'longitude': -73.98963911,
#    u'postalCode': u'',
#    u'stAddress1': u'Joralemon St & Adams St',
#    u'stAddress2': u'',
#    u'stationName': u'Joralemon St & Adams St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 236,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7284186,
#    u'location': u'',
#    u'longitude': -73.98713956,
#    u'postalCode': u'',
#    u'stAddress1': u'St Marks Pl & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'St Marks Pl & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 237,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73047309,
#    u'location': u'',
#    u'longitude': -73.98672378,
#    u'postalCode': u'',
#    u'stAddress1': u'E 11 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 11 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 238,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7361967,
#    u'location': u'',
#    u'longitude': -74.00859207,
#    u'postalCode': u'',
#    u'stAddress1': u'Bank St & Washington St',
#    u'stAddress2': u'',
#    u'stationName': u'Bank St & Washington St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 239,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69196566,
#    u'location': u'',
#    u'longitude': -73.9813018,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby St & Fleet St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby St & Fleet St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 241,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68981035,
#    u'location': u'',
#    u'longitude': -73.97493121,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & S Portland Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & S Portland Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 242,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69788349,
#    u'location': u'',
#    u'longitude': -73.97350332,
#    u'postalCode': u'',
#    u'stAddress1': u'Flushing Ave & Carlton Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Flushing Ave & Carlton Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 243,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.688226,
#    u'location': u'',
#    u'longitude': -73.979382,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Rockwell Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Rockwell Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 244,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69196035,
#    u'location': u'',
#    u'longitude': -73.96536851,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby Ave & Hall St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby Ave & Hall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 245,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69327018,
#    u'location': u'',
#    u'longitude': -73.97703874,
#    u'postalCode': u'',
#    u'stAddress1': u'Myrtle Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Myrtle Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 247,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73535398,
#    u'location': u'',
#    u'longitude': -74.00483091,
#    u'postalCode': u'',
#    u'stAddress1': u'Perry St & Bleecker St',
#    u'stAddress2': u'',
#    u'stationName': u'Perry St & Bleecker St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 248,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72185379,
#    u'location': u'',
#    u'longitude': -74.00771779,
#    u'postalCode': u'',
#    u'stAddress1': u'Laight St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Laight St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 249,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71870987,
#    u'location': u'',
#    u'longitude': -74.0090009,
#    u'postalCode': u'',
#    u'stAddress1': u'Harrison St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Harrison St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 250,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72456089,
#    u'location': u'',
#    u'longitude': -73.99565293,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & Jersey St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & Jersey St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 40},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 251,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72317958,
#    u'location': u'',
#    u'longitude': -73.99480012,
#    u'postalCode': u'',
#    u'stAddress1': u'Mott St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'Mott St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 252,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73226398,
#    u'location': u'',
#    u'longitude': -73.99852205,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Washington Sq',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Washington Sq',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 253,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73543934,
#    u'location': u'',
#    u'longitude': -73.99453948,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 5 Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 3},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 254,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73532427,
#    u'location': u'',
#    u'longitude': -73.99800419,
#    u'postalCode': u'',
#    u'stAddress1': u'W 11 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 11 St & 6 Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 257,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71939226,
#    u'location': u'',
#    u'longitude': -74.00247214,
#    u'postalCode': u'',
#    u'stAddress1': u'Lispenard St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Lispenard St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 258,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68940747,
#    u'location': u'',
#    u'longitude': -73.96885458,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & Vanderbilt Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & Vanderbilt Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 259,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70122128,
#    u'location': u'',
#    u'longitude': -74.01234218,
#    u'postalCode': u'',
#    u'stAddress1': u'South St & Whitehall St',
#    u'stAddress2': u'',
#    u'stationName': u'South St & Whitehall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 260,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70365182,
#    u'location': u'',
#    u'longitude': -74.01167797,
#    u'postalCode': u'',
#    u'stAddress1': u'Broad St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Broad St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 34},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 261,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69474881,
#    u'location': u'',
#    u'longitude': -73.98362464,
#    u'postalCode': u'',
#    u'stAddress1': u'Johnson St & Gold St',
#    u'stAddress2': u'',
#    u'stationName': u'Johnson St & Gold St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 262,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69178232,
#    u'location': u'',
#    u'longitude': -73.97372989,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Park',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 263,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71729,
#    u'location': u'',
#    u'longitude': -73.996375,
#    u'postalCode': u'',
#    u'stAddress1': u'Elizabeth St & Hester St',
#    u'stAddress2': u'',
#    u'stationName': u'Elizabeth St & Hester St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 264,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70706456,
#    u'location': u'',
#    u'longitude': -74.00731853,
#    u'postalCode': u'',
#    u'stAddress1': u'Maiden Ln & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'Maiden Ln & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 265,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72229346,
#    u'location': u'',
#    u'longitude': -73.99147535,
#    u'postalCode': u'',
#    u'stAddress1': u'Stanton St & Chrystie St',
#    u'stAddress2': u'',
#    u'stationName': u'Stanton St & Chrystie St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 266,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72368361,
#    u'location': u'',
#    u'longitude': -73.97574813,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 48,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 267,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75097711,
#    u'location': u'',
#    u'longitude': -73.98765428,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 36 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 36 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 57},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 268,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71910537,
#    u'location': u'',
#    u'longitude': -73.99973337,
#    u'postalCode': u'',
#    u'stAddress1': u'Howard St & Centre St',
#    u'stAddress2': u'',
#    u'stationName': u'Howard St & Centre St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 270,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69308257,
#    u'location': u'',
#    u'longitude': -73.97178913,
#    u'postalCode': u'',
#    u'stAddress1': u'Adelphi St & Myrtle Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Adelphi St & Myrtle Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 271,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68528172,
#    u'location': u'',
#    u'longitude': -73.97805813,
#    u'postalCode': u'',
#    u'stAddress1': u'Ashland Pl & Hanson Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Ashland Pl & Hanson Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 274,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68691865,
#    u'location': u'',
#    u'longitude': -73.976682,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 275,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68650065,
#    u'location': u'',
#    u'longitude': -73.96563307,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Ave & Greene Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Ave & Greene Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 276,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71748752,
#    u'location': u'',
#    u'longitude': -74.0104554,
#    u'postalCode': u'',
#    u'stAddress1': u'Duane St & Greenwich St',
#    u'stAddress2': u'',
#    u'stationName': u'Duane St & Greenwich St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 278,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.69766564,
#    u'location': u'',
#    u'longitude': -73.98476437,
#    u'postalCode': u'',
#    u'stAddress1': u'Concord St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Concord St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 279,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.707873,
#    u'location': u'',
#    u'longitude': -74.00167,
#    u'postalCode': u'',
#    u'stAddress1': u'Peck Slip & Front St',
#    u'stAddress2': u'',
#    u'stationName': u'Peck Slip & Front St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 280,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73331967,
#    u'location': u'',
#    u'longitude': -73.99510132,
#    u'postalCode': u'',
#    u'stAddress1': u'E 10 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 10 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 48,
#    u'city': u'',
#    u'id': 281,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7643971,
#    u'location': u'',
#    u'longitude': -73.97371465,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand Army Plaza & Central Park S',
#    u'stAddress2': u'',
#    u'stationName': u'Grand Army Plaza & Central Park S',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 282,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70827295,
#    u'location': u'',
#    u'longitude': -73.96834101,
#    u'postalCode': u'',
#    u'stAddress1': u'Kent Ave & S 11 St',
#    u'stAddress2': u'',
#    u'stationName': u'Kent Ave & S 11 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 284,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7390169121,
#    u'location': u'',
#    u'longitude': -74.0026376103,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich Ave & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich Ave & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 285,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73454567,
#    u'location': u'',
#    u'longitude': -73.99074142,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & E 14 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & E 14 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 289,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.6845683,
#    u'location': u'',
#    u'longitude': -73.95881081,
#    u'postalCode': u'',
#    u'stAddress1': u'Monroe St & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Monroe St & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 290,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.76020258,
#    u'location': u'',
#    u'longitude': -73.96478473,
#    u'postalCode': u'',
#    u'stAddress1': u'2 Ave & E 58 St',
#    u'stAddress2': u'',
#    u'stationName': u'2 Ave & E 58 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 291,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.713126,
#    u'location': u'',
#    u'longitude': -73.984844,
#    u'postalCode': u'',
#    u'stAddress1': u'Madison St & Montgomery St',
#    u'stAddress2': u'',
#    u'stationName': u'Madison St & Montgomery St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 37,
#    u'city': u'',
#    u'id': 293,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73028666,
#    u'location': u'',
#    u'longitude': -73.9907647,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 294,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73049393,
#    u'location': u'',
#    u'longitude': -73.9957214,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Square E',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Square E',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 295,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71406667,
#    u'location': u'',
#    u'longitude': -73.99293911,
#    u'postalCode': u'',
#    u'stAddress1': u'Pike St & E Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Pike St & E Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 296,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71413089,
#    u'location': u'',
#    u'longitude': -73.9970468,
#    u'postalCode': u'',
#    u'stAddress1': u'Division St & Bowery',
#    u'stAddress2': u'',
#    u'stationName': u'Division St & Bowery',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 297,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.734232,
#    u'location': u'',
#    u'longitude': -73.986923,
#    u'postalCode': u'',
#    u'stAddress1': u'E 15 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 15 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 298,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68683208,
#    u'location': u'',
#    u'longitude': -73.9796772,
#    u'postalCode': u'',
#    u'stAddress1': u'3 Ave & Schermerhorn St',
#    u'stAddress2': u'',
#    u'stationName': u'3 Ave & Schermerhorn St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 300,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.728145,
#    u'location': u'',
#    u'longitude': -73.990214,
#    u'postalCode': u'',
#    u'stAddress1': u'Shevchenko Pl & E 7 St',
#    u'stAddress2': u'',
#    u'stationName': u'Shevchenko Pl & E 7 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 301,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72217444,
#    u'location': u'',
#    u'longitude': -73.98368779,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue B',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue B',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 302,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72082834,
#    u'location': u'',
#    u'longitude': -73.97793172,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 303,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72362738,
#    u'location': u'',
#    u'longitude': -73.99949601,
#    u'postalCode': u'',
#    u'stAddress1': u'Mercer St & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Mercer St & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 304,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70463334,
#    u'location': u'',
#    u'longitude': -74.01361706,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & Battery Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & Battery Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 305,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.76095756,
#    u'location': u'',
#    u'longitude': -73.96724467,
#    u'postalCode': u'',
#    u'stAddress1': u'E 58 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 58 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 35,
#    u'city': u'',
#    u'id': 306,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70823502,
#    u'location': u'',
#    u'longitude': -74.00530063,
#    u'postalCode': u'',
#    u'stAddress1': u'Cliff St & Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Cliff St & Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 307,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71427487,
#    u'location': u'',
#    u'longitude': -73.98990025,
#    u'postalCode': u'',
#    u'stAddress1': u'Canal St & Rutgers St',
#    u'stAddress2': u'',
#    u'stationName': u'Canal St & Rutgers St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 308,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71307916,
#    u'location': u'',
#    u'longitude': -73.99851193,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Oliver St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Oliver St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 39,
#    u'city': u'',
#    u'id': 309,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7149787,
#    u'location': u'',
#    u'longitude': -74.013012,
#    u'postalCode': u'',
#    u'stAddress1': u'Murray St & West St',
#    u'stAddress2': u'',
#    u'stationName': u'Murray St & West St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 310,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.68926942,
#    u'location': u'',
#    u'longitude': -73.98912867,
#    u'postalCode': u'',
#    u'stAddress1': u'State St & Smith St',
#    u'stAddress2': u'',
#    u'stationName': u'State St & Smith St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 311,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7172274,
#    u'location': u'',
#    u'longitude': -73.98802084,
#    u'postalCode': u'',
#    u'stAddress1': u'Norfolk St & Broome St',
#    u'stAddress2': u'',
#    u'stationName': u'Norfolk St & Broome St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
# ...
#    u'longitude': -73.98316936,
#    u'postalCode': u'',
#    u'stAddress1': u'W 43 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 43 St & 6 Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 57},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 525,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75594159,
#    u'location': u'',
#    u'longitude': -74.0021163,
#    u'postalCode': u'',
#    u'stAddress1': u'W 34 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 34 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 526,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74765947,
#    u'location': u'',
#    u'longitude': -73.98490707,
#    u'postalCode': u'',
#    u'stAddress1': u'E 33 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 33 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 29,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 527,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.744023,
#    u'location': u'',
#    u'longitude': -73.976056,
#    u'postalCode': u'',
#    u'stAddress1': u'E 33 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 33 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 528,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74290902,
#    u'location': u'',
#    u'longitude': -73.97706058,
#    u'postalCode': u'',
#    u'stAddress1': u'2 Ave & E 31 St',
#    u'stAddress2': u'',
#    u'stationName': u'2 Ave & E 31 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 529,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.7575699,
#    u'location': u'',
#    u'longitude': -73.99098507,
#    u'postalCode': u'',
#    u'stAddress1': u'W 42 St & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 42 St & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 530,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.771522,
#    u'location': u'',
#    u'longitude': -73.990541,
#    u'postalCode': u'',
#    u'stAddress1': u'11 Ave & W 59 St',
#    u'stAddress2': u'',
#    u'stationName': u'11 Ave & W 59 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 531,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71893904,
#    u'location': u'',
#    u'longitude': -73.99266288,
#    u'postalCode': u'',
#    u'stAddress1': u'Forsyth St & Broome St',
#    u'stAddress2': u'',
#    u'stationName': u'Forsyth St & Broome St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 532,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.710451,
#    u'location': u'',
#    u'longitude': -73.960876,
#    u'postalCode': u'',
#    u'stAddress1': u'S 5 Pl & S 4 St',
#    u'stAddress2': u'',
#    u'stationName': u'S 5 Pl & S 4 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 46,
#    u'city': u'',
#    u'id': 533,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75299641,
#    u'location': u'',
#    u'longitude': -73.98721619,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 39 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 39 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 534,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70255065,
#    u'location': u'',
#    u'longitude': -74.0127234,
#    u'postalCode': u'',
#    u'stAddress1': u'Water - Whitehall Plaza',
#    u'stAddress2': u'',
#    u'stationName': u'Water - Whitehall Plaza',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 536,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74144387,
#    u'location': u'',
#    u'longitude': -73.97536082,
#    u'postalCode': u'',
#    u'stAddress1': u'1 Ave & E 30 St',
#    u'stAddress2': u'',
#    u'stationName': u'1 Ave & E 30 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 537,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74025878,
#    u'location': u'',
#    u'longitude': -73.98409214,
#    u'postalCode': u'',
#    u'stAddress1': u'Lexington Ave & E 24 St',
#    u'stAddress2': u'',
#    u'stationName': u'Lexington Ave & E 24 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 39,
#    u'city': u'',
#    u'id': 538,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75666,
#    u'location': u'',
#    u'longitude': -73.976684,
#    u'postalCode': u'',
#    u'stAddress1': u'E 48 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 48 St & Madison Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 539,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71534825,
#    u'location': u'',
#    u'longitude': -73.96024116,
#    u'postalCode': u'',
#    u'stAddress1': u'Metropolitan Ave & Bedford Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Metropolitan Ave & Bedford Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 38,
#    u'city': u'',
#    u'id': 540,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74147286,
#    u'location': u'',
#    u'longitude': -73.98320928,
#    u'postalCode': u'',
#    u'stAddress1': u'Lexington Ave & E 26 St',
#    u'stAddress2': u'',
#    u'stationName': u'Lexington Ave & E 26 St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 38},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 545,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.736502,
#    u'location': u'',
#    u'longitude': -73.97809472,
#    u'postalCode': u'',
#    u'stAddress1': u'E 23 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 23 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 546,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.74444921,
#    u'location': u'',
#    u'longitude': -73.98303529,
#    u'postalCode': u'',
#    u'stAddress1': u'E 30 St & Park Ave S',
#    u'stAddress2': u'',
#    u'stationName': u'E 30 St & Park Ave S',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 38},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 2000,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70255088,
#    u'location': u'',
#    u'longitude': -73.98940236,
#    u'postalCode': u'',
#    u'stAddress1': u'Front St & Washington St',
#    u'stAddress2': u'',
#    u'stationName': u'Front St & Washington St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 2001,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.699773,
#    u'location': u'',
#    u'longitude': -73.979927,
#    u'postalCode': u'',
#    u'stAddress1': u'Sands St & Navy St',
#    u'stAddress2': u'',
#    u'stationName': u'Sands St & Navy St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 15},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 2002,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.716887,
#    u'location': u'',
#    u'longitude': -73.963198,
#    u'postalCode': u'',
#    u'stAddress1': u'Wythe Ave & Metropolitan Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Wythe Ave & Metropolitan Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 2003,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.73416059,
#    u'location': u'',
#    u'longitude': -73.98024289,
#    u'postalCode': u'',
#    u'stAddress1': u'1 Ave & E 18 St',
#    u'stAddress2': u'STX 277',
#    u'stationName': u'1 Ave & E 18 St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 2004,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.724399,
#    u'location': u'',
#    u'longitude': -74.004704,
#    u'postalCode': u'',
#    u'stAddress1': u'6 Ave & Broome St',
#    u'stAddress2': u'',
#    u'stationName': u'6 Ave & Broome St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 2005,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70531194,
#    u'location': u'',
#    u'longitude': -73.97100056,
#    u'postalCode': u'',
#    u'stAddress1': u'Railroad Ave & Kay Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Railroad Ave & Kay Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 11},
#   {u'altitude': u'',
#    u'availableBikes': 25,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 2006,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.76590936,
#    u'location': u'',
#    u'longitude': -73.97634151,
#    u'postalCode': u'',
#    u'stAddress1': u'Central Park S & 6 Ave',
#    u'stAddress2': u'STX 287',
#    u'stationName': u'Central Park S & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 49},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 2008,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.70569254,
#    u'location': u'',
#    u'longitude': -74.01677685,
#    u'postalCode': u'',
#    u'stAddress1': u'Little West St & 1 Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Little West St & 1 Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 2009,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.71117444,
#    u'location': u'',
#    u'longitude': -73.99682619,
#    u'postalCode': u'',
#    u'stAddress1': u'Catherine St & Monroe St',
#    u'stAddress2': u'',
#    u'stationName': u'Catherine St & Monroe St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 37,
#    u'city': u'',
#    u'id': 2010,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.72165481,
#    u'location': u'',
#    u'longitude': -74.00234737,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand St & Greene St',
#    u'stAddress2': u'',
#    u'stationName': u'Grand St & Greene St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 2012,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.739445,
#    u'location': u'',
#    u'longitude': -73.976806,
#    u'postalCode': u'',
#    u'stAddress1': u'E 27 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 27 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 2017,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75022392,
#    u'location': u'',
#    u'longitude': -73.97121414,
#    u'postalCode': u'',
#    u'stAddress1': u'E 43 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 43 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 32,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 2021,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75929124,
#    u'location': u'',
#    u'longitude': -73.98859651,
#    u'postalCode': u'',
#    u'stAddress1': u'W 45 St & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 45 St & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 2022,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75849116,
#    u'location': u'',
#    u'longitude': -73.95920622,
#    u'postalCode': u'',
#    u'stAddress1': u'E 59 St & Sutton Pl',
#    u'stAddress2': u'',
#    u'stationName': u'E 59 St & Sutton Pl',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 2023,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.75968085,
#    u'location': u'',
#    u'longitude': -73.97031366,
#    u'postalCode': u'',
#    u'stAddress1': u'E 55 St & Lexington Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 55 St & Lexington Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 3002,
#    u'landMark': u'',
#    u'lastCommunicationTime': None,
#    u'latitude': 40.711512,
#    u'location': u'',
#    u'longitude': -74.015756,
#    u'postalCode': u'',
#    u'stAddress1': u'South End Ave & Liberty St',
#    u'stAddress2': u'',
#    u'stationName': u'South End Ave & Liberty St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25}]}

# %%
r.json().keys()
# Out:
# [u'executionTime', u'stationBeanList']

# %%
r.json()['stationBeanList']
# Out:
# [{u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 72,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.76727216,
#   u'location': u'',
#   u'longitude': -73.99392888,
#   u'postalCode': u'',
#   u'stAddress1': u'W 52 St & 11 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 52 St & 11 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 31,
#   u'city': u'',
#   u'id': 79,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71911552,
#   u'location': u'',
#   u'longitude': -74.00666661,
#   u'postalCode': u'',
#   u'stAddress1': u'Franklin St & W Broadway',
#   u'stAddress2': u'',
#   u'stationName': u'Franklin St & W Broadway',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 33},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 23,
#   u'city': u'',
#   u'id': 82,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71117416,
#   u'location': u'',
#   u'longitude': -74.00016545,
#   u'postalCode': u'',
#   u'stAddress1': u'St James Pl & Pearl St',
#   u'stAddress2': u'',
#   u'stationName': u'St James Pl & Pearl St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 7,
#   u'availableDocks': 54,
#   u'city': u'',
#   u'id': 83,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68382604,
#   u'location': u'',
#   u'longitude': -73.97632328,
#   u'postalCode': u'',
#   u'stAddress1': u'Atlantic Ave & Fort Greene Pl',
#   u'stAddress2': u'',
#   u'stationName': u'Atlantic Ave & Fort Greene Pl',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 62},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 34,
#   u'city': u'',
#   u'id': 116,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74177603,
#   u'location': u'',
#   u'longitude': -74.00149746,
#   u'postalCode': u'',
#   u'stAddress1': u'W 17 St & 8 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 17 St & 8 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 13,
#   u'city': u'',
#   u'id': 119,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69608941,
#   u'location': u'',
#   u'longitude': -73.97803415,
#   u'postalCode': u'',
#   u'stAddress1': u'Park Ave & St Edwards St',
#   u'stAddress2': u'',
#   u'stationName': u'Park Ave & St Edwards St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 19},
#  {u'altitude': u'',
#   u'availableBikes': 6,
#   u'availableDocks': 12,
#   u'city': u'',
#   u'id': 120,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68676793,
#   u'location': u'',
#   u'longitude': -73.95928168,
#   u'postalCode': u'',
#   u'stAddress1': u'Lexington Ave & Classon Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Lexington Ave & Classon Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 19},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 127,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73172428,
#   u'location': u'',
#   u'longitude': -74.00674436,
#   u'postalCode': u'',
#   u'stAddress1': u'Barrow St & Hudson St',
#   u'stAddress2': u'',
#   u'stationName': u'Barrow St & Hudson St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 17,
#   u'city': u'',
#   u'id': 128,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72710258,
#   u'location': u'',
#   u'longitude': -74.00297088,
#   u'postalCode': u'',
#   u'stAddress1': u'MacDougal St & Prince St',
#   u'stAddress2': u'',
#   u'stationName': u'MacDougal St & Prince St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 30},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 42,
#   u'city': u'',
#   u'id': 137,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.761628,
#   u'location': u'',
#   u'longitude': -73.972924,
#   u'postalCode': u'',
#   u'stAddress1': u'E 56 St & Madison Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 56 St & Madison Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 46},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 143,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69239502,
#   u'location': u'',
#   u'longitude': -73.99337909,
#   u'postalCode': u'',
#   u'stAddress1': u'Clinton St & Joralemon St',
#   u'stAddress2': u'',
#   u'stationName': u'Clinton St & Joralemon St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 24},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 17,
#   u'city': u'',
#   u'id': 144,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69839895,
#   u'location': u'',
#   u'longitude': -73.98068914,
#   u'postalCode': u'',
#   u'stAddress1': u'Nassau St & Navy St',
#   u'stAddress2': u'',
#   u'stationName': u'Nassau St & Navy St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 19},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 146,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71625008,
#   u'location': u'',
#   u'longitude': -74.0091059,
#   u'postalCode': u'',
#   u'stAddress1': u'Hudson St & Reade St',
#   u'stAddress2': u'',
#   u'stationName': u'Hudson St & Reade St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 20,
#   u'city': u'',
#   u'id': 147,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71542197,
#   u'location': u'',
#   u'longitude': -74.01121978,
#   u'postalCode': u'',
#   u'stAddress1': u'Greenwich St & Warren St',
#   u'stAddress2': u'',
#   u'stationName': u'Greenwich St & Warren St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 33},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 22,
#   u'city': u'',
#   u'id': 150,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7208736,
#   u'location': u'',
#   u'longitude': -73.98085795,
#   u'postalCode': u'',
#   u'stAddress1': u'E 2 St & Avenue C',
#   u'stAddress2': u'',
#   u'stationName': u'E 2 St & Avenue C',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 14,
#   u'availableDocks': 17,
#   u'city': u'',
#   u'id': 151,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7218158,
#   u'location': u'',
#   u'longitude': -73.99720307,
#   u'postalCode': u'',
#   u'stAddress1': u'Cleveland Pl & Spring St',
#   u'stAddress2': u'',
#   u'stationName': u'Cleveland Pl & Spring St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 33},
#  {u'altitude': u'',
#   u'availableBikes': 7,
#   u'availableDocks': 20,
#   u'city': u'',
#   u'id': 152,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71473993,
#   u'location': u'',
#   u'longitude': -74.00910627,
#   u'postalCode': u'',
#   u'stAddress1': u'Warren St & Church St',
#   u'stAddress2': u'',
#   u'stationName': u'Warren St & Church St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 29},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 46,
#   u'city': u'',
#   u'id': 153,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.752062307,
#   u'location': u'',
#   u'longitude': -73.9816324043,
#   u'postalCode': u'',
#   u'stAddress1': u'E 40 St & 5 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 40 St & 5 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 55},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 11,
#   u'city': u'',
#   u'id': 157,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69089272,
#   u'location': u'',
#   u'longitude': -73.99612349,
#   u'postalCode': u'',
#   u'stAddress1': u'Henry St & Atlantic Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Henry St & Atlantic Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 18,
#   u'city': u'',
#   u'id': 160,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.748238,
#   u'location': u'',
#   u'longitude': -73.978311,
#   u'postalCode': u'',
#   u'stAddress1': u'E 37 St & Lexington Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 37 St & Lexington Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 26},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 23,
#   u'city': u'',
#   u'id': 161,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72917025,
#   u'location': u'',
#   u'longitude': -73.99810231,
#   u'postalCode': u'',
#   u'stAddress1': u'LaGuardia Pl & W 3 St',
#   u'stAddress2': u'',
#   u'stationName': u'LaGuardia Pl & W 3 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 35},
#  {u'altitude': u'',
#   u'availableBikes': 26,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 164,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75323098,
#   u'location': u'',
#   u'longitude': -73.97032517,
#   u'postalCode': u'',
#   u'stAddress1': u'E 47 St & 2 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 47 St & 2 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 47},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 36,
#   u'city': u'',
#   u'id': 167,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7489006,
#   u'location': u'',
#   u'longitude': -73.97604882,
#   u'postalCode': u'',
#   u'stAddress1': u'E 39 St & 3 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 39 St & 3 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 41},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 37,
#   u'city': u'',
#   u'id': 168,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73971301,
#   u'location': u'',
#   u'longitude': -73.99456405,
#   u'postalCode': u'',
#   u'stAddress1': u'W 18 St & 6 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 18 St & 6 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 47},
#  {u'altitude': u'',
#   u'availableBikes': 22,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 173,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.76064679,
#   u'location': u'',
#   u'longitude': -73.98442659,
#   u'postalCode': u'',
#   u'stAddress1': u'Broadway & W 49 St',
#   u'stAddress2': u'',
#   u'stationName': u'Broadway & W 49 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 51},
#  {u'altitude': u'',
#   u'availableBikes': 14,
#   u'availableDocks': 15,
#   u'city': u'',
#   u'id': 174,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7381765,
#   u'location': u'',
#   u'longitude': -73.97738662,
#   u'postalCode': u'',
#   u'stAddress1': u'E 25 St & 1 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 25 St & 1 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 30},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 44,
#   u'city': u'',
#   u'id': 195,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70905623,
#   u'location': u'',
#   u'longitude': -74.01043382,
#   u'postalCode': u'',
#   u'stAddress1': u'Liberty St & Broadway',
#   u'stAddress2': u'',
#   u'stationName': u'Liberty St & Broadway',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 45},
#  {u'altitude': u'',
#   u'availableBikes': 7,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 212,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74334935,
#   u'location': u'',
#   u'longitude': -74.00681753,
#   u'postalCode': u'',
#   u'stAddress1': u'W 16 St & The High Line',
#   u'stAddress2': u'',
#   u'stationName': u'W 16 St & The High Line',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 28},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 216,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70037867,
#   u'location': u'',
#   u'longitude': -73.99548059,
#   u'postalCode': u'',
#   u'stAddress1': u'Columbia Heights & Cranberry St',
#   u'stAddress2': u'',
#   u'stationName': u'Columbia Heights & Cranberry St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 21,
#   u'availableDocks': 18,
#   u'city': u'',
#   u'id': 217,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70277159,
#   u'location': u'',
#   u'longitude': -73.99383605,
#   u'postalCode': u'',
#   u'stAddress1': u'Old Fulton St',
#   u'stAddress2': u'',
#   u'stationName': u'Old Fulton St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 26,
#   u'city': u'',
#   u'id': 218,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69028437,
#   u'location': u'',
#   u'longitude': -73.98707105,
#   u'postalCode': u'',
#   u'stAddress1': u'Gallatin Pl & Livingston St',
#   u'stAddress2': u'',
#   u'stationName': u'Gallatin Pl & Livingston St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 38},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 24,
#   u'city': u'',
#   u'id': 223,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73781509,
#   u'location': u'',
#   u'longitude': -73.99994661,
#   u'postalCode': u'',
#   u'stAddress1': u'W 13 St & 7 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 13 St & 7 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 33},
#  {u'altitude': u'',
#   u'availableBikes': 7,
#   u'availableDocks': 23,
#   u'city': u'',
#   u'id': 224,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71146364,
#   u'location': u'',
#   u'longitude': -74.00552427,
#   u'postalCode': u'',
#   u'stAddress1': u'Spruce St & Nassau St',
#   u'stAddress2': u'',
#   u'stationName': u'Spruce St & Nassau St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 34,
#   u'city': u'',
#   u'id': 225,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74195138,
#   u'location': u'',
#   u'longitude': -74.00803013,
#   u'postalCode': u'',
#   u'stAddress1': u'W 14 St & The High Line',
#   u'stAddress2': u'',
#   u'stationName': u'W 14 St & The High Line',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 37},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 51,
#   u'city': u'',
#   u'id': 228,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7546011026,
#   u'location': u'',
#   u'longitude': -73.971878855,
#   u'postalCode': u'',
#   u'stAddress1': u'E 48 St & 3 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 48 St & 3 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 55},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 16,
#   u'city': u'',
#   u'id': 229,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72743423,
#   u'location': u'',
#   u'longitude': -73.99379025,
#   u'postalCode': u'',
#   u'stAddress1': u'Great Jones St',
#   u'stAddress2': u'',
#   u'stationName': u'Great Jones St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 7,
#   u'availableDocks': 13,
#   u'city': u'',
#   u'id': 232,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69597683,
#   u'location': u'',
#   u'longitude': -73.99014892,
#   u'postalCode': u'',
#   u'stAddress1': u'Cadman Plaza E & Tillary St',
#   u'stAddress2': u'',
#   u'stationName': u'Cadman Plaza E & Tillary St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 21,
#   u'availableDocks': 17,
#   u'city': u'',
#   u'id': 233,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69246277,
#   u'location': u'',
#   u'longitude': -73.98963911,
#   u'postalCode': u'',
#   u'stAddress1': u'Joralemon St & Adams St',
#   u'stAddress2': u'',
#   u'stationName': u'Joralemon St & Adams St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 13,
#   u'availableDocks': 24,
#   u'city': u'',
#   u'id': 236,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7284186,
#   u'location': u'',
#   u'longitude': -73.98713956,
#   u'postalCode': u'',
#   u'stAddress1': u'St Marks Pl & 2 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'St Marks Pl & 2 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 27,
#   u'availableDocks': 10,
#   u'city': u'',
#   u'id': 237,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73047309,
#   u'location': u'',
#   u'longitude': -73.98672378,
#   u'postalCode': u'',
#   u'stAddress1': u'E 11 St & 2 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 11 St & 2 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 37},
#  {u'altitude': u'',
#   u'availableBikes': 15,
#   u'availableDocks': 16,
#   u'city': u'',
#   u'id': 238,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7361967,
#   u'location': u'',
#   u'longitude': -74.00859207,
#   u'postalCode': u'',
#   u'stAddress1': u'Bank St & Washington St',
#   u'stAddress2': u'',
#   u'stationName': u'Bank St & Washington St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 239,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69196566,
#   u'location': u'',
#   u'longitude': -73.9813018,
#   u'postalCode': u'',
#   u'stAddress1': u'Willoughby St & Fleet St',
#   u'stAddress2': u'',
#   u'stationName': u'Willoughby St & Fleet St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 20,
#   u'city': u'',
#   u'id': 241,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68981035,
#   u'location': u'',
#   u'longitude': -73.97493121,
#   u'postalCode': u'',
#   u'stAddress1': u'DeKalb Ave & S Portland Ave',
#   u'stAddress2': u'',
#   u'stationName': u'DeKalb Ave & S Portland Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 14,
#   u'availableDocks': 3,
#   u'city': u'',
#   u'id': 242,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69788349,
#   u'location': u'',
#   u'longitude': -73.97350332,
#   u'postalCode': u'',
#   u'stAddress1': u'Flushing Ave & Carlton Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Flushing Ave & Carlton Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 243,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.688226,
#   u'location': u'',
#   u'longitude': -73.979382,
#   u'postalCode': u'',
#   u'stAddress1': u'Fulton St & Rockwell Pl',
#   u'stAddress2': u'',
#   u'stationName': u'Fulton St & Rockwell Pl',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 30,
#   u'city': u'',
#   u'id': 244,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69196035,
#   u'location': u'',
#   u'longitude': -73.96536851,
#   u'postalCode': u'',
#   u'stAddress1': u'Willoughby Ave & Hall St',
#   u'stAddress2': u'',
#   u'stationName': u'Willoughby Ave & Hall St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 245,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69327018,
#   u'location': u'',
#   u'longitude': -73.97703874,
#   u'postalCode': u'',
#   u'stAddress1': u'Myrtle Ave & St Edwards St',
#   u'stAddress2': u'',
#   u'stationName': u'Myrtle Ave & St Edwards St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 8,
#   u'city': u'',
#   u'id': 247,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73535398,
#   u'location': u'',
#   u'longitude': -74.00483091,
#   u'postalCode': u'',
#   u'stAddress1': u'Perry St & Bleecker St',
#   u'stAddress2': u'',
#   u'stationName': u'Perry St & Bleecker St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 20},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 22,
#   u'city': u'',
#   u'id': 248,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72185379,
#   u'location': u'',
#   u'longitude': -74.00771779,
#   u'postalCode': u'',
#   u'stAddress1': u'Laight St & Hudson St',
#   u'stAddress2': u'',
#   u'stationName': u'Laight St & Hudson St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 25,
#   u'city': u'',
#   u'id': 249,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71870987,
#   u'location': u'',
#   u'longitude': -74.0090009,
#   u'postalCode': u'',
#   u'stAddress1': u'Harrison St & Hudson St',
#   u'stAddress2': u'',
#   u'stationName': u'Harrison St & Hudson St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 250,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72456089,
#   u'location': u'',
#   u'longitude': -73.99565293,
#   u'postalCode': u'',
#   u'stAddress1': u'Lafayette St & Jersey St',
#   u'stAddress2': u'',
#   u'stationName': u'Lafayette St & Jersey St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 40},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 22,
#   u'city': u'',
#   u'id': 251,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72317958,
#   u'location': u'',
#   u'longitude': -73.99480012,
#   u'postalCode': u'',
#   u'stAddress1': u'Mott St & Prince St',
#   u'stAddress2': u'',
#   u'stationName': u'Mott St & Prince St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 252,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73226398,
#   u'location': u'',
#   u'longitude': -73.99852205,
#   u'postalCode': u'',
#   u'stAddress1': u'MacDougal St & Washington Sq',
#   u'stAddress2': u'',
#   u'stationName': u'MacDougal St & Washington Sq',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 33},
#  {u'altitude': u'',
#   u'availableBikes': 0,
#   u'availableDocks': 3,
#   u'city': u'',
#   u'id': 253,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73543934,
#   u'location': u'',
#   u'longitude': -73.99453948,
#   u'postalCode': u'',
#   u'stAddress1': u'W 13 St & 5 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 13 St & 5 Ave',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 3},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 26,
#   u'city': u'',
#   u'id': 254,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73532427,
#   u'location': u'',
#   u'longitude': -73.99800419,
#   u'postalCode': u'',
#   u'stAddress1': u'W 11 St & 6 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 11 St & 6 Ave',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 29,
#   u'city': u'',
#   u'id': 257,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71939226,
#   u'location': u'',
#   u'longitude': -74.00247214,
#   u'postalCode': u'',
#   u'stAddress1': u'Lispenard St & Broadway',
#   u'stAddress2': u'',
#   u'stationName': u'Lispenard St & Broadway',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 258,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68940747,
#   u'location': u'',
#   u'longitude': -73.96885458,
#   u'postalCode': u'',
#   u'stAddress1': u'DeKalb Ave & Vanderbilt Ave',
#   u'stAddress2': u'',
#   u'stationName': u'DeKalb Ave & Vanderbilt Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 29,
#   u'city': u'',
#   u'id': 259,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70122128,
#   u'location': u'',
#   u'longitude': -74.01234218,
#   u'postalCode': u'',
#   u'stAddress1': u'South St & Whitehall St',
#   u'stAddress2': u'',
#   u'stationName': u'South St & Whitehall St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 30,
#   u'city': u'',
#   u'id': 260,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70365182,
#   u'location': u'',
#   u'longitude': -74.01167797,
#   u'postalCode': u'',
#   u'stAddress1': u'Broad St & Bridge St',
#   u'stAddress2': u'',
#   u'stationName': u'Broad St & Bridge St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 34},
#  {u'altitude': u'',
#   u'availableBikes': 17,
#   u'availableDocks': 10,
#   u'city': u'',
#   u'id': 261,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69474881,
#   u'location': u'',
#   u'longitude': -73.98362464,
#   u'postalCode': u'',
#   u'stAddress1': u'Johnson St & Gold St',
#   u'stAddress2': u'',
#   u'stationName': u'Johnson St & Gold St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 4,
#   u'availableDocks': 19,
#   u'city': u'',
#   u'id': 262,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69178232,
#   u'location': u'',
#   u'longitude': -73.97372989,
#   u'postalCode': u'',
#   u'stAddress1': u'Washington Park',
#   u'stAddress2': u'',
#   u'stationName': u'Washington Park',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 18,
#   u'city': u'',
#   u'id': 263,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71729,
#   u'location': u'',
#   u'longitude': -73.996375,
#   u'postalCode': u'',
#   u'stAddress1': u'Elizabeth St & Hester St',
#   u'stAddress2': u'',
#   u'stationName': u'Elizabeth St & Hester St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 6,
#   u'availableDocks': 18,
#   u'city': u'',
#   u'id': 264,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70706456,
#   u'location': u'',
#   u'longitude': -74.00731853,
#   u'postalCode': u'',
#   u'stAddress1': u'Maiden Ln & Pearl St',
#   u'stAddress2': u'',
#   u'stationName': u'Maiden Ln & Pearl St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 19,
#   u'availableDocks': 15,
#   u'city': u'',
#   u'id': 265,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72229346,
#   u'location': u'',
#   u'longitude': -73.99147535,
#   u'postalCode': u'',
#   u'stAddress1': u'Stanton St & Chrystie St',
#   u'stAddress2': u'',
#   u'stationName': u'Stanton St & Chrystie St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 35},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 12,
#   u'city': u'',
#   u'id': 266,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72368361,
#   u'location': u'',
#   u'longitude': -73.97574813,
#   u'postalCode': u'',
#   u'stAddress1': u'Avenue D & E 8 St',
#   u'stAddress2': u'',
#   u'stationName': u'Avenue D & E 8 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 24},
#  {u'altitude': u'',
#   u'availableBikes': 48,
#   u'availableDocks': 9,
#   u'city': u'',
#   u'id': 267,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75097711,
#   u'location': u'',
#   u'longitude': -73.98765428,
#   u'postalCode': u'',
#   u'stAddress1': u'Broadway & W 36 St',
#   u'stAddress2': u'',
#   u'stationName': u'Broadway & W 36 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 57},
#  {u'altitude': u'',
#   u'availableBikes': 14,
#   u'availableDocks': 11,
#   u'city': u'',
#   u'id': 268,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71910537,
#   u'location': u'',
#   u'longitude': -73.99973337,
#   u'postalCode': u'',
#   u'stAddress1': u'Howard St & Centre St',
#   u'stAddress2': u'',
#   u'stationName': u'Howard St & Centre St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 26},
#  {u'altitude': u'',
#   u'availableBikes': 14,
#   u'availableDocks': 9,
#   u'city': u'',
#   u'id': 270,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69308257,
#   u'location': u'',
#   u'longitude': -73.97178913,
#   u'postalCode': u'',
#   u'stAddress1': u'Adelphi St & Myrtle Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Adelphi St & Myrtle Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 4,
#   u'availableDocks': 25,
#   u'city': u'',
#   u'id': 271,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68528172,
#   u'location': u'',
#   u'longitude': -73.97805813,
#   u'postalCode': u'',
#   u'stAddress1': u'Ashland Pl & Hanson Pl',
#   u'stAddress2': u'',
#   u'stationName': u'Ashland Pl & Hanson Pl',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 25,
#   u'city': u'',
#   u'id': 274,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68691865,
#   u'location': u'',
#   u'longitude': -73.976682,
#   u'postalCode': u'',
#   u'stAddress1': u'Lafayette Ave & Fort Greene Pl',
#   u'stAddress2': u'',
#   u'stationName': u'Lafayette Ave & Fort Greene Pl',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 14,
#   u'city': u'',
#   u'id': 275,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68650065,
#   u'location': u'',
#   u'longitude': -73.96563307,
#   u'postalCode': u'',
#   u'stAddress1': u'Washington Ave & Greene Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Washington Ave & Greene Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 19},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 19,
#   u'city': u'',
#   u'id': 276,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71748752,
#   u'location': u'',
#   u'longitude': -74.0104554,
#   u'postalCode': u'',
#   u'stAddress1': u'Duane St & Greenwich St',
#   u'stAddress2': u'',
#   u'stationName': u'Duane St & Greenwich St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 25},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 16,
#   u'city': u'',
#   u'id': 278,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69766564,
#   u'location': u'',
#   u'longitude': -73.98476437,
#   u'postalCode': u'',
#   u'stAddress1': u'Concord St & Bridge St',
#   u'stAddress2': u'',
#   u'stationName': u'Concord St & Bridge St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 19},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 32,
#   u'city': u'',
#   u'id': 279,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.707873,
#   u'location': u'',
#   u'longitude': -74.00167,
#   u'postalCode': u'',
#   u'stAddress1': u'Peck Slip & Front St',
#   u'stAddress2': u'',
#   u'stationName': u'Peck Slip & Front St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 36},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 280,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73331967,
#   u'location': u'',
#   u'longitude': -73.99510132,
#   u'postalCode': u'',
#   u'stAddress1': u'E 10 St & 5 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 10 St & 5 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 48,
#   u'city': u'',
#   u'id': 281,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7643971,
#   u'location': u'',
#   u'longitude': -73.97371465,
#   u'postalCode': u'',
#   u'stAddress1': u'Grand Army Plaza & Central Park S',
#   u'stAddress2': u'',
#   u'stationName': u'Grand Army Plaza & Central Park S',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 59},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 17,
#   u'city': u'',
#   u'id': 282,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70827295,
#   u'location': u'',
#   u'longitude': -73.96834101,
#   u'postalCode': u'',
#   u'stAddress1': u'Kent Ave & S 11 St',
#   u'stAddress2': u'',
#   u'stationName': u'Kent Ave & S 11 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 13,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 284,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7390169121,
#   u'location': u'',
#   u'longitude': -74.0026376103,
#   u'postalCode': u'',
#   u'stAddress1': u'Greenwich Ave & 8 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Greenwich Ave & 8 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 43},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 34,
#   u'city': u'',
#   u'id': 285,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73454567,
#   u'location': u'',
#   u'longitude': -73.99074142,
#   u'postalCode': u'',
#   u'stAddress1': u'Broadway & E 14 St',
#   u'stAddress2': u'',
#   u'stationName': u'Broadway & E 14 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 47},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 13,
#   u'city': u'',
#   u'id': 289,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.6845683,
#   u'location': u'',
#   u'longitude': -73.95881081,
#   u'postalCode': u'',
#   u'stAddress1': u'Monroe St & Classon Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Monroe St & Classon Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 19},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 19,
#   u'city': u'',
#   u'id': 290,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.76020258,
#   u'location': u'',
#   u'longitude': -73.96478473,
#   u'postalCode': u'',
#   u'stAddress1': u'2 Ave & E 58 St',
#   u'stAddress2': u'',
#   u'stationName': u'2 Ave & E 58 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 29},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 18,
#   u'city': u'',
#   u'id': 291,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.713126,
#   u'location': u'',
#   u'longitude': -73.984844,
#   u'postalCode': u'',
#   u'stAddress1': u'Madison St & Montgomery St',
#   u'stAddress2': u'',
#   u'stationName': u'Madison St & Montgomery St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 20},
#  {u'altitude': u'',
#   u'availableBikes': 17,
#   u'availableDocks': 37,
#   u'city': u'',
#   u'id': 293,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73028666,
#   u'location': u'',
#   u'longitude': -73.9907647,
#   u'postalCode': u'',
#   u'stAddress1': u'Lafayette St & E 8 St',
#   u'stAddress2': u'',
#   u'stationName': u'Lafayette St & E 8 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 55},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 26,
#   u'city': u'',
#   u'id': 294,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73049393,
#   u'location': u'',
#   u'longitude': -73.9957214,
#   u'postalCode': u'',
#   u'stAddress1': u'Washington Square E',
#   u'stAddress2': u'',
#   u'stationName': u'Washington Square E',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 30},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 22,
#   u'city': u'',
#   u'id': 295,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71406667,
#   u'location': u'',
#   u'longitude': -73.99293911,
#   u'postalCode': u'',
#   u'stAddress1': u'Pike St & E Broadway',
#   u'stAddress2': u'',
#   u'stationName': u'Pike St & E Broadway',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 24},
#  {u'altitude': u'',
#   u'availableBikes': 24,
#   u'availableDocks': 10,
#   u'city': u'',
#   u'id': 296,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71413089,
#   u'location': u'',
#   u'longitude': -73.9970468,
#   u'postalCode': u'',
#   u'stAddress1': u'Division St & Bowery',
#   u'stAddress2': u'',
#   u'stationName': u'Division St & Bowery',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 35},
#  {u'altitude': u'',
#   u'availableBikes': 16,
#   u'availableDocks': 10,
#   u'city': u'',
#   u'id': 297,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.734232,
#   u'location': u'',
#   u'longitude': -73.986923,
#   u'postalCode': u'',
#   u'stAddress1': u'E 15 St & 3 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 15 St & 3 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 298,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68683208,
#   u'location': u'',
#   u'longitude': -73.9796772,
#   u'postalCode': u'',
#   u'stAddress1': u'3 Ave & Schermerhorn St',
#   u'stAddress2': u'',
#   u'stationName': u'3 Ave & Schermerhorn St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 35},
#  {u'altitude': u'',
#   u'availableBikes': 23,
#   u'availableDocks': 31,
#   u'city': u'',
#   u'id': 300,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.728145,
#   u'location': u'',
#   u'longitude': -73.990214,
#   u'postalCode': u'',
#   u'stAddress1': u'Shevchenko Pl & E 7 St',
#   u'stAddress2': u'',
#   u'stationName': u'Shevchenko Pl & E 7 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 55},
#  {u'altitude': u'',
#   u'availableBikes': 19,
#   u'availableDocks': 17,
#   u'city': u'',
#   u'id': 301,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72217444,
#   u'location': u'',
#   u'longitude': -73.98368779,
#   u'postalCode': u'',
#   u'stAddress1': u'E 2 St & Avenue B',
#   u'stAddress2': u'',
#   u'stationName': u'E 2 St & Avenue B',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 37},
#  {u'altitude': u'',
#   u'availableBikes': 17,
#   u'availableDocks': 6,
#   u'city': u'',
#   u'id': 302,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72082834,
#   u'location': u'',
#   u'longitude': -73.97793172,
#   u'postalCode': u'',
#   u'stAddress1': u'Avenue D & E 3 St',
#   u'stAddress2': u'',
#   u'stationName': u'Avenue D & E 3 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 19,
#   u'availableDocks': 11,
#   u'city': u'',
#   u'id': 303,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72362738,
#   u'location': u'',
#   u'longitude': -73.99949601,
#   u'postalCode': u'',
#   u'stAddress1': u'Mercer St & Spring St',
#   u'stAddress2': u'',
#   u'stationName': u'Mercer St & Spring St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 0,
#   u'availableDocks': 34,
#   u'city': u'',
#   u'id': 304,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70463334,
#   u'location': u'',
#   u'longitude': -74.01361706,
#   u'postalCode': u'',
#   u'stAddress1': u'Broadway & Battery Pl',
#   u'stAddress2': u'',
#   u'stationName': u'Broadway & Battery Pl',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 36},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 305,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.76095756,
#   u'location': u'',
#   u'longitude': -73.96724467,
#   u'postalCode': u'',
#   u'stAddress1': u'E 58 St & 3 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 58 St & 3 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 33},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 35,
#   u'city': u'',
#   u'id': 306,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70823502,
#   u'location': u'',
#   u'longitude': -74.00530063,
#   u'postalCode': u'',
#   u'stAddress1': u'Cliff St & Fulton St',
#   u'stAddress2': u'',
#   u'stationName': u'Cliff St & Fulton St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 37},
#  {u'altitude': u'',
#   u'availableBikes': 16,
#   u'availableDocks': 14,
#   u'city': u'',
#   u'id': 307,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71427487,
#   u'location': u'',
#   u'longitude': -73.98990025,
#   u'postalCode': u'',
#   u'stAddress1': u'Canal St & Rutgers St',
#   u'stAddress2': u'',
#   u'stationName': u'Canal St & Rutgers St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 3,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 308,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71307916,
#   u'location': u'',
#   u'longitude': -73.99851193,
#   u'postalCode': u'',
#   u'stAddress1': u'St James Pl & Oliver St',
#   u'stAddress2': u'',
#   u'stationName': u'St James Pl & Oliver St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 39,
#   u'city': u'',
#   u'id': 309,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7149787,
#   u'location': u'',
#   u'longitude': -74.013012,
#   u'postalCode': u'',
#   u'stAddress1': u'Murray St & West St',
#   u'stAddress2': u'',
#   u'stationName': u'Murray St & West St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 41},
#  {u'altitude': u'',
#   u'availableBikes': 20,
#   u'availableDocks': 15,
#   u'city': u'',
#   u'id': 310,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.68926942,
#   u'location': u'',
#   u'longitude': -73.98912867,
#   u'postalCode': u'',
#   u'stAddress1': u'State St & Smith St',
#   u'stAddress2': u'',
#   u'stationName': u'State St & Smith St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 36},
#  {u'altitude': u'',
#   u'availableBikes': 7,
#   u'availableDocks': 24,
#   u'city': u'',
#   u'id': 311,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7172274,
#   u'location': u'',
#   u'longitude': -73.98802084,
#   u'postalCode': u'',
#   u'stAddress1': u'Norfolk St & Broome St',
#   u'stAddress2': u'',
#   u'stationName': u'Norfolk St & Broome St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 23,
#   u'city': u'',
#   u'id': 312,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.722055,
#   u'location': u'',
#   u'longitude': -73.989111,
#   u'postalCode': u'',
#   u'stAddress1': u'Allen St & E Houston St',
#   u'stAddress2': u'',
#   u'stationName': u'Allen St & E Houston St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 16,
#   u'availableDocks': 3,
#   u'city': u'',
#   u'id': 313,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69610226,
#   u'location': u'',
#   u'longitude': -73.96751037,
#   u'postalCode': u'',
#   u'stAddress1': u'Washington Ave & Park Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Washington Ave & Park Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 23},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 35,
#   u'city': u'',
#   u'id': 314,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.69383,
#   u'location': u'',
#   u'longitude': -73.990539,
#   u'postalCode': u'',
#   u'stAddress1': u'Cadman Plaza West & Montague St',
#   u'stAddress2': u'',
#   u'stationName': u'Cadman Plaza West & Montague St',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 19,
#   u'availableDocks': 10,
#   u'city': u'',
#   u'id': 315,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70355377,
#   u'location': u'',
#   u'longitude': -74.00670227,
#   u'postalCode': u'',
#   u'stAddress1': u'South St & Gouverneur Ln',
#   u'stAddress2': u'',
#   u'stationName': u'South St & Gouverneur Ln',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 29},
#  {u'altitude': u'',
# ...
#   u'availableDocks': 32,
#   u'city': u'',
#   u'id': 523,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75466591,
#   u'location': u'',
#   u'longitude': -73.99138152,
#   u'postalCode': u'',
#   u'stAddress1': u'W 38 St & 8 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 38 St & 8 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 50},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 45,
#   u'city': u'',
#   u'id': 524,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75527307,
#   u'location': u'',
#   u'longitude': -73.98316936,
#   u'postalCode': u'',
#   u'stAddress1': u'W 43 St & 6 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 43 St & 6 Ave',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 57},
#  {u'altitude': u'',
#   u'availableBikes': 14,
#   u'availableDocks': 25,
#   u'city': u'',
#   u'id': 525,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75594159,
#   u'location': u'',
#   u'longitude': -74.0021163,
#   u'postalCode': u'',
#   u'stAddress1': u'W 34 St & 11 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 34 St & 11 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 4,
#   u'availableDocks': 34,
#   u'city': u'',
#   u'id': 526,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74765947,
#   u'location': u'',
#   u'longitude': -73.98490707,
#   u'postalCode': u'',
#   u'stAddress1': u'E 33 St & 5 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 33 St & 5 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 29,
#   u'availableDocks': 29,
#   u'city': u'',
#   u'id': 527,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.744023,
#   u'location': u'',
#   u'longitude': -73.976056,
#   u'postalCode': u'',
#   u'stAddress1': u'E 33 St & 2 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 33 St & 2 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 59},
#  {u'altitude': u'',
#   u'availableBikes': 8,
#   u'availableDocks': 29,
#   u'city': u'',
#   u'id': 528,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74290902,
#   u'location': u'',
#   u'longitude': -73.97706058,
#   u'postalCode': u'',
#   u'stAddress1': u'2 Ave & E 31 St',
#   u'stAddress2': u'',
#   u'stationName': u'2 Ave & E 31 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 20,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 529,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.7575699,
#   u'location': u'',
#   u'longitude': -73.99098507,
#   u'postalCode': u'',
#   u'stAddress1': u'W 42 St & 8 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 42 St & 8 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 41},
#  {u'altitude': u'',
#   u'availableBikes': 24,
#   u'availableDocks': 9,
#   u'city': u'',
#   u'id': 530,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.771522,
#   u'location': u'',
#   u'longitude': -73.990541,
#   u'postalCode': u'',
#   u'stAddress1': u'11 Ave & W 59 St',
#   u'stAddress2': u'',
#   u'stationName': u'11 Ave & W 59 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 36},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 27,
#   u'city': u'',
#   u'id': 531,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71893904,
#   u'location': u'',
#   u'longitude': -73.99266288,
#   u'postalCode': u'',
#   u'stAddress1': u'Forsyth St & Broome St',
#   u'stAddress2': u'',
#   u'stationName': u'Forsyth St & Broome St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 15,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 532,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.710451,
#   u'location': u'',
#   u'longitude': -73.960876,
#   u'postalCode': u'',
#   u'stAddress1': u'S 5 Pl & S 4 St',
#   u'stAddress2': u'',
#   u'stationName': u'S 5 Pl & S 4 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 43},
#  {u'altitude': u'',
#   u'availableBikes': 0,
#   u'availableDocks': 46,
#   u'city': u'',
#   u'id': 533,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75299641,
#   u'location': u'',
#   u'longitude': -73.98721619,
#   u'postalCode': u'',
#   u'stAddress1': u'Broadway & W 39 St',
#   u'stAddress2': u'',
#   u'stationName': u'Broadway & W 39 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 47},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 30,
#   u'city': u'',
#   u'id': 534,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70255065,
#   u'location': u'',
#   u'longitude': -74.0127234,
#   u'postalCode': u'',
#   u'stAddress1': u'Water - Whitehall Plaza',
#   u'stAddress2': u'',
#   u'stationName': u'Water - Whitehall Plaza',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 26,
#   u'city': u'',
#   u'id': 536,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74144387,
#   u'location': u'',
#   u'longitude': -73.97536082,
#   u'postalCode': u'',
#   u'stAddress1': u'1 Ave & E 30 St',
#   u'stAddress2': u'',
#   u'stationName': u'1 Ave & E 30 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 29},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 537,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74025878,
#   u'location': u'',
#   u'longitude': -73.98409214,
#   u'postalCode': u'',
#   u'stAddress1': u'Lexington Ave & E 24 St',
#   u'stAddress2': u'',
#   u'stationName': u'Lexington Ave & E 24 St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 0,
#   u'availableDocks': 39,
#   u'city': u'',
#   u'id': 538,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75666,
#   u'location': u'',
#   u'longitude': -73.976684,
#   u'postalCode': u'',
#   u'stAddress1': u'E 48 St & Madison Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 48 St & Madison Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 23,
#   u'availableDocks': 8,
#   u'city': u'',
#   u'id': 539,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71534825,
#   u'location': u'',
#   u'longitude': -73.96024116,
#   u'postalCode': u'',
#   u'stAddress1': u'Metropolitan Ave & Bedford Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Metropolitan Ave & Bedford Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 31},
#  {u'altitude': u'',
#   u'availableBikes': 0,
#   u'availableDocks': 38,
#   u'city': u'',
#   u'id': 540,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74147286,
#   u'location': u'',
#   u'longitude': -73.98320928,
#   u'postalCode': u'',
#   u'stAddress1': u'Lexington Ave & E 26 St',
#   u'stAddress2': u'',
#   u'stationName': u'Lexington Ave & E 26 St',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 38},
#  {u'altitude': u'',
#   u'availableBikes': 11,
#   u'availableDocks': 15,
#   u'city': u'',
#   u'id': 545,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.736502,
#   u'location': u'',
#   u'longitude': -73.97809472,
#   u'postalCode': u'',
#   u'stAddress1': u'E 23 St & 1 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 23 St & 1 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 23,
#   u'city': u'',
#   u'id': 546,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.74444921,
#   u'location': u'',
#   u'longitude': -73.98303529,
#   u'postalCode': u'',
#   u'stAddress1': u'E 30 St & Park Ave S',
#   u'stAddress2': u'',
#   u'stationName': u'E 30 St & Park Ave S',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 38},
#  {u'altitude': u'',
#   u'availableBikes': 10,
#   u'availableDocks': 19,
#   u'city': u'',
#   u'id': 2000,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70255088,
#   u'location': u'',
#   u'longitude': -73.98940236,
#   u'postalCode': u'',
#   u'stAddress1': u'Front St & Washington St',
#   u'stAddress2': u'',
#   u'stationName': u'Front St & Washington St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 30},
#  {u'altitude': u'',
#   u'availableBikes': 6,
#   u'availableDocks': 9,
#   u'city': u'',
#   u'id': 2001,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.699773,
#   u'location': u'',
#   u'longitude': -73.979927,
#   u'postalCode': u'',
#   u'stAddress1': u'Sands St & Navy St',
#   u'stAddress2': u'',
#   u'stationName': u'Sands St & Navy St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 15},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 15,
#   u'city': u'',
#   u'id': 2002,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.716887,
#   u'location': u'',
#   u'longitude': -73.963198,
#   u'postalCode': u'',
#   u'stAddress1': u'Wythe Ave & Metropolitan Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Wythe Ave & Metropolitan Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 27},
#  {u'altitude': u'',
#   u'availableBikes': 0,
#   u'availableDocks': 30,
#   u'city': u'',
#   u'id': 2003,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.73416059,
#   u'location': u'',
#   u'longitude': -73.98024289,
#   u'postalCode': u'',
#   u'stAddress1': u'1 Ave & E 18 St',
#   u'stAddress2': u'STX 277',
#   u'stationName': u'1 Ave & E 18 St',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 30},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 33,
#   u'city': u'',
#   u'id': 2004,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.724399,
#   u'location': u'',
#   u'longitude': -74.004704,
#   u'postalCode': u'',
#   u'stAddress1': u'6 Ave & Broome St',
#   u'stAddress2': u'',
#   u'stationName': u'6 Ave & Broome St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 36},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 6,
#   u'city': u'',
#   u'id': 2005,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70531194,
#   u'location': u'',
#   u'longitude': -73.97100056,
#   u'postalCode': u'',
#   u'stAddress1': u'Railroad Ave & Kay Ave',
#   u'stAddress2': u'',
#   u'stationName': u'Railroad Ave & Kay Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 11},
#  {u'altitude': u'',
#   u'availableBikes': 25,
#   u'availableDocks': 23,
#   u'city': u'',
#   u'id': 2006,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.76590936,
#   u'location': u'',
#   u'longitude': -73.97634151,
#   u'postalCode': u'',
#   u'stAddress1': u'Central Park S & 6 Ave',
#   u'stAddress2': u'STX 287',
#   u'stationName': u'Central Park S & 6 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 49},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 10,
#   u'city': u'',
#   u'id': 2008,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.70569254,
#   u'location': u'',
#   u'longitude': -74.01677685,
#   u'postalCode': u'',
#   u'stAddress1': u'Little West St & 1 Pl',
#   u'stAddress2': u'',
#   u'stationName': u'Little West St & 1 Pl',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 24},
#  {u'altitude': u'',
#   u'availableBikes': 5,
#   u'availableDocks': 29,
#   u'city': u'',
#   u'id': 2009,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.71117444,
#   u'location': u'',
#   u'longitude': -73.99682619,
#   u'postalCode': u'',
#   u'stAddress1': u'Catherine St & Monroe St',
#   u'stAddress2': u'',
#   u'stationName': u'Catherine St & Monroe St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 35},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 37,
#   u'city': u'',
#   u'id': 2010,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.72165481,
#   u'location': u'',
#   u'longitude': -74.00234737,
#   u'postalCode': u'',
#   u'stAddress1': u'Grand St & Greene St',
#   u'stAddress2': u'',
#   u'stationName': u'Grand St & Greene St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 1,
#   u'availableDocks': 34,
#   u'city': u'',
#   u'id': 2012,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.739445,
#   u'location': u'',
#   u'longitude': -73.976806,
#   u'postalCode': u'',
#   u'stAddress1': u'E 27 St & 1 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 27 St & 1 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 35},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 30,
#   u'city': u'',
#   u'id': 2017,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75022392,
#   u'location': u'',
#   u'longitude': -73.97121414,
#   u'postalCode': u'',
#   u'stAddress1': u'E 43 St & 2 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 43 St & 2 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 32,
#   u'availableDocks': 10,
#   u'city': u'',
#   u'id': 2021,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75929124,
#   u'location': u'',
#   u'longitude': -73.98859651,
#   u'postalCode': u'',
#   u'stAddress1': u'W 45 St & 8 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 45 St & 8 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 43},
#  {u'altitude': u'',
#   u'availableBikes': 0,
#   u'availableDocks': 33,
#   u'city': u'',
#   u'id': 2022,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75849116,
#   u'location': u'',
#   u'longitude': -73.95920622,
#   u'postalCode': u'',
#   u'stAddress1': u'E 59 St & Sutton Pl',
#   u'stAddress2': u'',
#   u'stationName': u'E 59 St & Sutton Pl',
#   u'statusKey': 3,
#   u'statusValue': u'Not In Service',
#   u'testStation': False,
#   u'totalDocks': 33},
#  {u'altitude': u'',
#   u'availableBikes': 2,
#   u'availableDocks': 34,
#   u'city': u'',
#   u'id': 2023,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.75968085,
#   u'location': u'',
#   u'longitude': -73.97031366,
#   u'postalCode': u'',
#   u'stAddress1': u'E 55 St & Lexington Ave',
#   u'stAddress2': u'',
#   u'stationName': u'E 55 St & Lexington Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 36},
#  {u'altitude': u'',
#   u'availableBikes': 12,
#   u'availableDocks': 12,
#   u'city': u'',
#   u'id': 3002,
#   u'landMark': u'',
#   u'lastCommunicationTime': None,
#   u'latitude': 40.711512,
#   u'location': u'',
#   u'longitude': -74.015756,
#   u'postalCode': u'',
#   u'stAddress1': u'South End Ave & Liberty St',
#   u'stAddress2': u'',
#   u'stationName': u'South End Ave & Liberty St',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 25}]

# %%
key_list = [] #unique list of keys for each station listing
for station in r.json()['stationBeanList']:
    for k in station.keys():
        if k not in key_list:
            key_list.append(k)

# %%
key_list
# Out:
# [u'availableDocks',
#  u'totalDocks',
#  u'city',
#  u'altitude',
#  u'stAddress2',
#  u'longitude',
#  u'lastCommunicationTime',
#  u'postalCode',
#  u'statusValue',
#  u'testStation',
#  u'stAddress1',
#  u'stationName',
#  u'landMark',
#  u'latitude',
#  u'statusKey',
#  u'availableBikes',
#  u'id',
#  u'location']

# %%
from pandas.io.json import json_normalize

df = json_normalize(r.json()['stationBeanList'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

df['availableBikes'].hist()
plt.show()

# %%
df['totalDocks'].hist()
plt.show()

# %%
df['testStation'].hist()
plt.show()

# %%
df['testStation']
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: testStation, Length: 332, dtype: bool

# %%
df['testStation'].count()
# Out:
# 332

# %%
df['testStation'].max()
# Out:
# False

# %%
key_list
# Out:
# [u'availableDocks',
#  u'totalDocks',
#  u'city',
#  u'altitude',
#  u'stAddress2',
#  u'longitude',
#  u'lastCommunicationTime',
#  u'postalCode',
#  u'statusValue',
#  u'testStation',
#  u'stAddress1',
#  u'stationName',
#  u'landMark',
#  u'latitude',
#  u'statusKey',
#  u'availableBikes',
#  u'id',
#  u'location']

# %%
df[df['testStation']==True].count()
# Out:
# altitude                 0
# availableBikes           0
# availableDocks           0
# city                     0
# id                       0
# landMark                 0
# lastCommunicationTime    0
# latitude                 0
# location                 0
# longitude                0
# postalCode               0
# stAddress1               0
# stAddress2               0
# stationName              0
# statusKey                0
# statusValue              0
# testStation              0
# totalDocks               0
# dtype: int64

# %%
df[df['statusValue']=='In Service']['availableBikes'].mean()
# Out:
# 9.9841772151898738

# %%
df['availableBikes'].median()
# Out:
# 7.0

# %%
((df['totalDocks']-df['availableDocks'])-df['availableBikes']).mean()
# Out:
# 0.99397590361445787

# %%
import sqlite3 as lite

con = lite.connect('citi_bike1.db')
cur = con.cursor()

with con:
    cur.execute('CREATE TABLE citibike_reference (id INT PRIMARY KEY, totalDocks INT, city TEXT, altitude INT, stAddress2 TEXT, longitude NUMERIC, postalCode TEXT, testStation TEXT, stAddress1 TEXT, stationName TEXT, landMark TEXT, latitude NUMERIC, location TEXT )')

# %%
#a prepared SQL statement we're going to execute over and over again
sql = "INSERT INTO citibike_reference (id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?)"

#for loop to populate values in the database
with con:
    for station in r.json()['stationBeanList']:
        #id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location)
        cur.execute(sql,(station['id'],station['totalDocks'],station['city'],station['altitude'],station['stAddress2'],station['longitude'],station['postalCode'],station['testStation'],station['stAddress1'],station['stationName'],station['landMark'],station['latitude'],station['location']))

# %%
#extract the column from the DataFrame and put them into a list
station_ids = df['id'].tolist() 

#add the '_' to the station name and also add the data type for SQLite
station_ids = ['_' + str(x) + ' INT' for x in station_ids] 

#create the table
#in this case, we're concatentating the string and joining all the station ids (now with '_' and 'INT' added)
with con:
    cur.execute("CREATE TABLE available_bikes ( execution_time INT, " +  ", ".join(station_ids) + ");")

# %%
# a package with datetime objects
import sqlite3 as lite
con = lite.connect('citi_bike1.db')
import time

# a package for parsing a string into a Python datetime object
from dateutil.parser import parse 

import collections


#take the string and parse it into a Python datetime object
exec_time = parse(r.json()['executionTime'])

# %%
with con:
    cur.execute('INSERT INTO available_bikes (execution_time) VALUES (?)', (exec_time.strftime('%s'),))

# %%
id_bikes = collections.defaultdict(int) #defaultdict to store available bikes by station

#loop through the stations in the station list
for station in r.json()['stationBeanList']:
    id_bikes[station['id']] = station['availableBikes']

#iterate through the defaultdict to update the values in the database
with con:
    for k, v in id_bikes.iteritems():
        cur.execute("UPDATE available_bikes SET _" + str(k) + " = " + str(v) + " WHERE execution_time = " + exec_time.strftime('%s') + ";")

# %%
for i in range(60):
    r = requests.get('http://www.citibikenyc.com/stations/json')
    exec_time = parse(r.json()['executionTime'])

    cur.execute('INSERT INTO available_bikes (execution_time) VALUES (?)', (exec_time.strftime('%s'),))
    con.commit()

    id_bikes = collections.defaultdict(int)
    for station in r.json()['stationBeanList']:
        id_bikes[station['id']] = station['availableBikes']

    for k, v in id_bikes.iteritems():
        cur.execute("UPDATE available_bikes SET _" + str(k) + " = " + str(v) + " WHERE execution_time = " + exec_time.strftime('%s') + ";")
    con.commit()

    time.sleep(60)

con.close() #close the database connection when done

# %%
con.close()

# %%
import pandas as pd
import sqlite3 as lite

con = lite.connect('citi_bike.db')
cur = con.cursor()

# %%
con.close()

# %%
import requests

# %%
import pandas as pd
import sqlite3 as lite

con = lite.connect('citi_bike1.db')
cur = con.cursor()

# %%
df = pd.read_sql_query("SELECT * FROM available_bikes ORDER BY execution_time",con,index_col='execution_time')

# %%
hour_change = collections.defaultdict(int)
for col in df.columns:
    station_vals = df[col].tolist()
    station_id = col[1:] #trim the "_"
    station_change = 0
    for k,v in enumerate(station_vals):
        if k < len(station_vals) - 1:
            station_change += abs(station_vals[k] - station_vals[k+1])
    hour_change[int(station_id)] = station_change #convert the station id back to integer
    
def keywithmaxval(d):
    # create a list of the dict's keys and values; 
    v = list(d.values())
    k = list(d.keys())

    # return the key with the max value
    return k[v.index(max(v))]

# assign the max key to max_station
max_station = keywithmaxval(hour_change)

# %%
#query sqlite for reference information
cur.execute("SELECT id, stationname, latitude, longitude FROM citibike_reference WHERE id = ?", (max_station,))
data = cur.fetchone()
print "The most active station is station id %s at %s latitude: %s longitude: %s " % data
print "With " + str(hour_change[379]) + " bicycles coming and going in the hour between " + datetime.datetime.fromtimestamp(int(df.index[0])).strftime('%Y-%m-%dT%H:%M:%S') + " and " + datetime.datetime.fromtimestamp(int(df.index[-1])).strftime('%Y-%m-%dT%H:%M:%S')
# Out:
# The most active station is station id 490 at 8 Ave & W 33 St latitude: 40.751551 longitude: -73.993934
# With 42 bicycles coming and going in the hour between 2015-03-13T07:05:01 and 2015-03-13T08:38:01

# %%
import matplotlib.pyplot as plt

plt.bar(hour_change.keys(), hour_change.values())
plt.show()

# %%
df.head
# Out:
# <bound method DataFrame.head of                 _72  _79  _82  _83  _116  _119  _120  _127  _128  _137  ...   \
# execution_time                                                          ...
# 1426230301       12   10    5    0     7     4    10    10    17     3  ...
# 1426230421       12   10    4    0     7     4    10    10    17     3  ...
# 1426230481       12   10    4    0     7     4    10    10    17     3  ...
# 1426230542       12   10    4    0     7     4    10    10    17     3  ...
# 1426230601       12   10    4    0     7     4    10    10    16     3  ...
# 1426230662       12   10    4    0     7     4    11    11    16     3  ...
# 1426230721       12   10    4    0     7     4    11    11    16     3  ...
# 1426230781       12   10    4    0     7     4    11    11    16     3  ...
# 1426230841       12   10    4    0     7     4    11    11    16     3  ...
# 1426230901       12   10    4    0     7     4    11    11    16     3  ...
# 1426230961       12   10    4    0     7     4    11    12    16     3  ...
# 1426231021       12   10    4    0     8     4    11    12    16     3  ...
# 1426231081       12   10    4    0     8     4    11    12    16     3  ...
# 1426231142       12   10    4    0     8     4    11    11    16     3  ...
# 1426231201       12   10    4    0     8     4    11    11    16     3  ...
# 1426231381       12   10    4    0     8     4    11    10    16     3  ...
# 1426231442       12   10    4    0     6     4    11    10    16     3  ...
# 1426231501       12   10    4    0     6     4    11    10    16     3  ...
# 1426231561       12   10    4    0     6     4    10    11    16     3  ...
# 1426231622       12   10    4    0     6     4    10    11    16     3  ...
# 1426231681       12   10    4    0     5     4    10    11    16     3  ...
# 1426231741       12   10    4    0     5     4    10    11    16     3  ...
# 1426231801       13   10    4    0     5     4    10    11    15     3  ...
# 1426231861       13   10    4    0     5     4    10    11    15     3  ...
# 1426231922       13   10    4    0     5     4    10    11    14     3  ...
# 1426231981       13   10    4    0     5     4    10    11    15     3  ...
# 1426232041       13   10    4    0     5     4    10    11    15     3  ...
# 1426232101       13   10    4    0     5     4    10    11    15     3  ...
# 1426232161       15   10    4    0     5     3    10    10    15     4  ...
# 1426232221       15   10    4    0     4     3    10    10    15     4  ...
# ...             ...  ...  ...  ...   ...   ...   ...   ...   ...   ...  ...
# 1426232342       15   10    4    0     4     3    10    10    17     4  ...
# 1426232401       15   10    4    0     4     3    10    10    17     4  ...
# 1426232461       14   10    4    0     4     4    11    10    18     4  ...
# 1426232521       14   10    4    0     4     4    11    10    18     4  ...
# 1426232581       14   10    4    0     4     4    11    10    18     4  ...
# 1426232642       14   10    4    0     4     4    11    10    18     4  ...
# 1426234501       13   10    4    1    12     3     9     7    13    11  ...
# 1426234622       13   10    4    1    12     3     8     7    10    12  ...
# 1426234622       13   10    4    1    12     3     8     7    10    12  ...
# 1426234681       13   10    4    1    13     3     8     7     8    12  ...
# 1426234741       12   10    4    1    13     3     8     7     8    12  ...
# 1426234802       12   10    4    1    12     3     8     7     6    12  ...
# 1426234922       12   10    4    1    12     3     9     5     5    13  ...
# 1426234922       12   10    4    1    12     3     9     5     5    13  ...
# 1426234981       12   10    4    1    12     3     9     5     5    13  ...
# 1426235102       12   10    4    1    13     3     9     4     6    13  ...
# 1426235102       12   10    4    1    13     3     9     4     6    13  ...
# 1426235221       12   10    4    1    13     3     9     3     6    14  ...
# 1426235222       12   10    4    1    13     3     9     3     6    14  ...
# 1426235281       12   10    3    1    13     3     9     3     6    14  ...
# 1426235341       12   10    3    1    13     3     8     3     6    14  ...
# 1426235401       12   11    3    1    13     3     8     3     6    14  ...
# 1426235461       12   11    3    1    13     3     8     3     7    13  ...
# 1426235582       12   11    3    1    13     3     8     3     4    14  ...
# 1426235582       12   11    3    1    13     3     8     3     4    14  ...
# 1426235641       12   11    3    1    13     3     8     3     4    14  ...
# 1426235761       11   10    3    1    14     3     8     3     5    15  ...
# 1426235761       11   10    3    1    14     3     8     3     5    15  ...
# 1426235881       12   10    3    1    14     3     8     4     5    16  ...
# 1426235881       12   10    3    1    14     3     8     4     5    16  ...
#
#                 _2006  _2008  _2009  _2010  _2012  _2017  _2021  _2022  _2023  \
# execution_time
# 1426230301         38     16     15      1     11      3     10      0      0
# 1426230421         38     16     15      1     11      3     10      0      0
# 1426230481         38     16     15      1     11      3     10      0      0
# 1426230542         38     15     15      1     11      3     10      0      0
# 1426230601         37     14     15      1     12      3     10      0      0
# 1426230662         37     14     15      1     13      3     10      0      0
# 1426230721         37     14     15      1     13      3     10      0      1
# 1426230781         37     14     15      1     13      3     10      0      1
# 1426230841         37     14     15      1     13      3     10      0      1
# 1426230901         37     14     15      1     13      3     10      0      1
# 1426230961         37     14     15      1     14      3     10      0      1
# 1426231021         37     14     15      1     14      3     10      0      1
# 1426231081         37     14     15      1     14      3     10      0      1
# 1426231142         37     14     15      1     14      3     10      0      1
# 1426231201         36     14     15      1     15      3     10      0      1
# 1426231381         36     13     15      1     16      3      8      0      1
# 1426231442         36     13     15      1     17      4      8      0      1
# 1426231501         36     14     14      1     17      4      7      0      1
# 1426231561         36     14     14      1     17      4      8      0      1
# 1426231622         36     14     14      1     17      3      8      0      1
# 1426231681         36     14     14      1     17      3      8      0      1
# 1426231741         36     14     14      1     17      3      8      0      1
# 1426231801         36     13     14      1     17      3      9      0      1
# 1426231861         36     13     14      1     17      3      9      0      1
# 1426231922         36     12     14      1     18      3      9      0      1
# 1426231981         36     12     14      1     18      3      8      0      1
# 1426232041         36     12     14      1     19      3      8      0      1
# 1426232101         38     13     15      1     19      3      8      0      1
# 1426232161         38     13     15      1     19      3      7      0      1
# 1426232221         38     13     15      1     19      3      7      0      1
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1426232342         38     13     14      1     19      3      7      0      1
# 1426232401         37     12     14      1     19      3      7      0      1
# 1426232461         37     12     14      1     20      3      7      0      1
# 1426232521         37     12     14      1     21      3      7      0      1
# 1426232581         37     11     14      1     21      3      7      0      1
# 1426232642         37     11     14      1     21      3      7      0      1
# 1426234501         39      8      9      2     22      5      5      0      4
# 1426234622         39      8      9      2     22      5      5      0      4
# 1426234622         39      8      9      2     22      5      5      0      4
# 1426234681         39      8      9      2     22      5      5      0      4
# 1426234741         39      8      9      2     22      5      5      0      4
# 1426234802         38      8     10      2     22      5      5      0      4
# 1426234922         38      7     10      2     22      5      5      0      6
# 1426234922         38      7     10      2     22      5      5      0      6
# 1426234981         38      7     10      2     22      6      5      0      6
# 1426235102         38      7     10      2     23      7      5      0      7
# 1426235102         38      7     10      2     23      7      5      0      7
# 1426235221         38      7     10      2     23      7      5      0      7
# 1426235222         38      7     10      2     23      7      5      0      7
# 1426235281         38      7     10      2     25      7      5      0      7
# 1426235341         38      8     10      2     25      7      5      0      7
# 1426235401         38      8     10      2     25      7      5      0      7
# 1426235461         38      8     10      2     25      7      5      0      7
# 1426235582         38      9     10      2     25      7      5      0      7
# 1426235582         38      9     10      2     25      7      5      0      7
# 1426235641         38      9     10      2     25      6      5      0      7
# 1426235761         38      9     10      1     25      6      5      0      6
# 1426235761         38      9     10      1     25      6      5      0      6
# 1426235881         38      9     10      1     26      6      5      0      6
# 1426235881         38      9     10      1     26      6      5      0      6
#
#                 _3002
# execution_time
# 1426230301         11
# 1426230421         11
# 1426230481         11
# 1426230542         11
# 1426230601         11
# 1426230662         11
# 1426230721         11
# 1426230781         11
# 1426230841         11
# 1426230901         11
# 1426230961         11
# 1426231021         11
# 1426231081         11
# 1426231142         11
# 1426231201         11
# 1426231381         12
# 1426231442         12
# 1426231501         12
# 1426231561         12
# 1426231622         12
# 1426231681         12
# 1426231741         12
# 1426231801         12
# 1426231861         12
# 1426231922         12
# 1426231981         12
# 1426232041         12
# 1426232101         12
# 1426232161         11
# 1426232221         11
# ...               ...
# 1426232342         11
# 1426232401         10
# 1426232461         10
# 1426232521         10
# 1426232581         10
# 1426232642         10
# 1426234501          7
# 1426234622          7
# 1426234622          7
# 1426234681          7
# 1426234741          7
# 1426234802          6
# 1426234922          6
# 1426234922          6
# 1426234981          6
# 1426235102          6
# 1426235102          6
# 1426235221          6
# 1426235222          6
# 1426235281          6
# 1426235341          6
# 1426235401          6
# 1426235461          6
# 1426235582          6
# 1426235582          6
# 1426235641          6
# 1426235761          5
# 1426235761          5
# 1426235881          5
# 1426235881          5
#
# [61 rows x 332 columns]>

# %%
df
# Out:
#                 _72  _79  _82  _83  _116  _119  _120  _127  _128  _137  ...   \
# execution_time                                                          ...
# 1426230301       12   10    5    0     7     4    10    10    17     3  ...
# 1426230421       12   10    4    0     7     4    10    10    17     3  ...
# 1426230481       12   10    4    0     7     4    10    10    17     3  ...
# 1426230542       12   10    4    0     7     4    10    10    17     3  ...
# 1426230601       12   10    4    0     7     4    10    10    16     3  ...
# 1426230662       12   10    4    0     7     4    11    11    16     3  ...
# 1426230721       12   10    4    0     7     4    11    11    16     3  ...
# 1426230781       12   10    4    0     7     4    11    11    16     3  ...
# 1426230841       12   10    4    0     7     4    11    11    16     3  ...
# 1426230901       12   10    4    0     7     4    11    11    16     3  ...
# 1426230961       12   10    4    0     7     4    11    12    16     3  ...
# 1426231021       12   10    4    0     8     4    11    12    16     3  ...
# 1426231081       12   10    4    0     8     4    11    12    16     3  ...
# 1426231142       12   10    4    0     8     4    11    11    16     3  ...
# 1426231201       12   10    4    0     8     4    11    11    16     3  ...
# 1426231381       12   10    4    0     8     4    11    10    16     3  ...
# 1426231442       12   10    4    0     6     4    11    10    16     3  ...
# 1426231501       12   10    4    0     6     4    11    10    16     3  ...
# 1426231561       12   10    4    0     6     4    10    11    16     3  ...
# 1426231622       12   10    4    0     6     4    10    11    16     3  ...
# 1426231681       12   10    4    0     5     4    10    11    16     3  ...
# 1426231741       12   10    4    0     5     4    10    11    16     3  ...
# 1426231801       13   10    4    0     5     4    10    11    15     3  ...
# 1426231861       13   10    4    0     5     4    10    11    15     3  ...
# 1426231922       13   10    4    0     5     4    10    11    14     3  ...
# 1426231981       13   10    4    0     5     4    10    11    15     3  ...
# 1426232041       13   10    4    0     5     4    10    11    15     3  ...
# 1426232101       13   10    4    0     5     4    10    11    15     3  ...
# 1426232161       15   10    4    0     5     3    10    10    15     4  ...
# 1426232221       15   10    4    0     4     3    10    10    15     4  ...
# ...             ...  ...  ...  ...   ...   ...   ...   ...   ...   ...  ...
# 1426232342       15   10    4    0     4     3    10    10    17     4  ...
# 1426232401       15   10    4    0     4     3    10    10    17     4  ...
# 1426232461       14   10    4    0     4     4    11    10    18     4  ...
# 1426232521       14   10    4    0     4     4    11    10    18     4  ...
# 1426232581       14   10    4    0     4     4    11    10    18     4  ...
# 1426232642       14   10    4    0     4     4    11    10    18     4  ...
# 1426234501       13   10    4    1    12     3     9     7    13    11  ...
# 1426234622       13   10    4    1    12     3     8     7    10    12  ...
# 1426234622       13   10    4    1    12     3     8     7    10    12  ...
# 1426234681       13   10    4    1    13     3     8     7     8    12  ...
# 1426234741       12   10    4    1    13     3     8     7     8    12  ...
# 1426234802       12   10    4    1    12     3     8     7     6    12  ...
# 1426234922       12   10    4    1    12     3     9     5     5    13  ...
# 1426234922       12   10    4    1    12     3     9     5     5    13  ...
# 1426234981       12   10    4    1    12     3     9     5     5    13  ...
# 1426235102       12   10    4    1    13     3     9     4     6    13  ...
# 1426235102       12   10    4    1    13     3     9     4     6    13  ...
# 1426235221       12   10    4    1    13     3     9     3     6    14  ...
# 1426235222       12   10    4    1    13     3     9     3     6    14  ...
# 1426235281       12   10    3    1    13     3     9     3     6    14  ...
# 1426235341       12   10    3    1    13     3     8     3     6    14  ...
# 1426235401       12   11    3    1    13     3     8     3     6    14  ...
# 1426235461       12   11    3    1    13     3     8     3     7    13  ...
# 1426235582       12   11    3    1    13     3     8     3     4    14  ...
# 1426235582       12   11    3    1    13     3     8     3     4    14  ...
# 1426235641       12   11    3    1    13     3     8     3     4    14  ...
# 1426235761       11   10    3    1    14     3     8     3     5    15  ...
# 1426235761       11   10    3    1    14     3     8     3     5    15  ...
# 1426235881       12   10    3    1    14     3     8     4     5    16  ...
# 1426235881       12   10    3    1    14     3     8     4     5    16  ...
#
#                 _2006  _2008  _2009  _2010  _2012  _2017  _2021  _2022  _2023  \
# execution_time
# 1426230301         38     16     15      1     11      3     10      0      0
# 1426230421         38     16     15      1     11      3     10      0      0
# 1426230481         38     16     15      1     11      3     10      0      0
# 1426230542         38     15     15      1     11      3     10      0      0
# 1426230601         37     14     15      1     12      3     10      0      0
# 1426230662         37     14     15      1     13      3     10      0      0
# 1426230721         37     14     15      1     13      3     10      0      1
# 1426230781         37     14     15      1     13      3     10      0      1
# 1426230841         37     14     15      1     13      3     10      0      1
# 1426230901         37     14     15      1     13      3     10      0      1
# 1426230961         37     14     15      1     14      3     10      0      1
# 1426231021         37     14     15      1     14      3     10      0      1
# 1426231081         37     14     15      1     14      3     10      0      1
# 1426231142         37     14     15      1     14      3     10      0      1
# 1426231201         36     14     15      1     15      3     10      0      1
# 1426231381         36     13     15      1     16      3      8      0      1
# 1426231442         36     13     15      1     17      4      8      0      1
# 1426231501         36     14     14      1     17      4      7      0      1
# 1426231561         36     14     14      1     17      4      8      0      1
# 1426231622         36     14     14      1     17      3      8      0      1
# 1426231681         36     14     14      1     17      3      8      0      1
# 1426231741         36     14     14      1     17      3      8      0      1
# 1426231801         36     13     14      1     17      3      9      0      1
# 1426231861         36     13     14      1     17      3      9      0      1
# 1426231922         36     12     14      1     18      3      9      0      1
# 1426231981         36     12     14      1     18      3      8      0      1
# 1426232041         36     12     14      1     19      3      8      0      1
# 1426232101         38     13     15      1     19      3      8      0      1
# 1426232161         38     13     15      1     19      3      7      0      1
# 1426232221         38     13     15      1     19      3      7      0      1
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1426232342         38     13     14      1     19      3      7      0      1
# 1426232401         37     12     14      1     19      3      7      0      1
# 1426232461         37     12     14      1     20      3      7      0      1
# 1426232521         37     12     14      1     21      3      7      0      1
# 1426232581         37     11     14      1     21      3      7      0      1
# 1426232642         37     11     14      1     21      3      7      0      1
# 1426234501         39      8      9      2     22      5      5      0      4
# 1426234622         39      8      9      2     22      5      5      0      4
# 1426234622         39      8      9      2     22      5      5      0      4
# 1426234681         39      8      9      2     22      5      5      0      4
# 1426234741         39      8      9      2     22      5      5      0      4
# 1426234802         38      8     10      2     22      5      5      0      4
# 1426234922         38      7     10      2     22      5      5      0      6
# 1426234922         38      7     10      2     22      5      5      0      6
# 1426234981         38      7     10      2     22      6      5      0      6
# 1426235102         38      7     10      2     23      7      5      0      7
# 1426235102         38      7     10      2     23      7      5      0      7
# 1426235221         38      7     10      2     23      7      5      0      7
# 1426235222         38      7     10      2     23      7      5      0      7
# 1426235281         38      7     10      2     25      7      5      0      7
# 1426235341         38      8     10      2     25      7      5      0      7
# 1426235401         38      8     10      2     25      7      5      0      7
# 1426235461         38      8     10      2     25      7      5      0      7
# 1426235582         38      9     10      2     25      7      5      0      7
# 1426235582         38      9     10      2     25      7      5      0      7
# 1426235641         38      9     10      2     25      6      5      0      7
# 1426235761         38      9     10      1     25      6      5      0      6
# 1426235761         38      9     10      1     25      6      5      0      6
# 1426235881         38      9     10      1     26      6      5      0      6
# 1426235881         38      9     10      1     26      6      5      0      6
#
#                 _3002
# execution_time
# 1426230301         11
# 1426230421         11
# 1426230481         11
# 1426230542         11
# 1426230601         11
# 1426230662         11
# 1426230721         11
# 1426230781         11
# 1426230841         11
# 1426230901         11
# 1426230961         11
# 1426231021         11
# 1426231081         11
# 1426231142         11
# 1426231201         11
# 1426231381         12
# 1426231442         12
# 1426231501         12
# 1426231561         12
# 1426231622         12
# 1426231681         12
# 1426231741         12
# 1426231801         12
# 1426231861         12
# 1426231922         12
# 1426231981         12
# 1426232041         12
# 1426232101         12
# 1426232161         11
# 1426232221         11
# ...               ...
# 1426232342         11
# 1426232401         10
# 1426232461         10
# 1426232521         10
# 1426232581         10
# 1426232642         10
# 1426234501          7
# 1426234622          7
# 1426234622          7
# 1426234681          7
# 1426234741          7
# 1426234802          6
# 1426234922          6
# 1426234922          6
# 1426234981          6
# 1426235102          6
# 1426235102          6
# 1426235221          6
# 1426235222          6
# 1426235281          6
# 1426235341          6
# 1426235401          6
# 1426235461          6
# 1426235582          6
# 1426235582          6
# 1426235641          6
# 1426235761          5
# 1426235761          5
# 1426235881          5
# 1426235881          5
#
# [61 rows x 332 columns]

# %%
from mpl_toolkits.basemap import Basemap
St latitude: 40.751551 longitude: -73.993934

# %%
m = Basemap(projection='npstere',boundinglat=40,lon_0=-74,resolution='l')
x, y = m(-73.993934, 40.751551)

# %%
map = Basemap(projection='merc', lat_0=40.751551, lon_0=-73.993934,
    resolution = 'h', area_thresh = 0.1,
    llcrnrlon=-73.75, llcrnrlat=40.5,
    urcrnrlon=-74.25, urcrnrlat=41)
 

map.drawmapboundary(fill_color='#85A6D9')
map.drawcoastlines(color='#6D5F47', linewidth=.4)
map.drawrivers(color='#6D5F47', linewidth=.4)
map.fillcontinents(color='white',lake_color='#85A6D9')
 
map.drawmeridians(np.arange(0, 360, 30))
map.drawparallels(np.arange(-90, 90, 30))

 
plt.show()
